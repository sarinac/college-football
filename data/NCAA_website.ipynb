# %% [markdown]
# # NCAA Website
#
# *Webscraping and finding out what I need...*
#
# I used the library BeautifulSoup to programatically get the results of each game in the 2019 college season. I used the <a href="https://www.ncaa.com/scoreboard/football/fbs/2019/01">NCAA's website</a> to find HTML tags holding the winner and loser's score and rank for each game, which I write into a DataFrame. I use the same process to collect data on which schools belong to which conference from <a href="https://www.ncaa.com/standings/football/fbs">this page</a>.

# %%
# Import libraries
import os
import logging
import simplejson
import json
import requests
from bs4 import BeautifulSoup
from urllib.request import urlretrieve
import cssutils

from datetime import datetime

import pandas as pd
import numpy as np

import networkx as nx

cssutils.log.setLevel(logging.CRITICAL)

# %load_ext nb_black

# %% [markdown]
# ## Collect Data on Games

# %% [markdown]
# ### 1 Sample

# %% [markdown]
# #### Scoreboard (Home) Page

# %%
# Read page
url = "https://www.ncaa.com/scoreboard/football/fbs/2019/01/all-conf"
response = requests.get(url)
soup = BeautifulSoup(response.content)

# %%
# Get date sections
date_sections = soup.find_all("div", attrs={"class": "gamePod_content-division"})

# Get 1 date section
date_section = date_sections[0]

# Get date from date section
date = date_section.find_all("h6")[0].contents[0]
print(date)

# Get games within date section
games = date_section.find_all(
    "div", attrs={"class": "gamePod gamePod-type-game status-final"}
)

# Get 1 game from games
game = games[0]
# Out:
# Saturday, August 24, 2019

# %%
# Get results
winner = game.find("li", attrs={"class": "winner"})
loser = game.find("li", attrs={"class": ""})

# Get states for winner and loser
sides = {"winner": winner, "loser": loser}
for side_name in sides:
    side = sides.get(side_name)
    team = side.find("span", attrs={"class": "gamePod-game-team-name"}).contents[0]
    score_pre = side.find("span", attrs={"class": "gamePod-game-team-score"}).contents
    score = score_pre[0] if len(score_pre) > 0 else np.nan
    rank_pre = side.find("span", attrs={"class": "gamePod-game-team-rank"}).contents
    rank = rank_pre[0] if len(rank_pre) > 0 else np.nan
    print(side_name, team, score, rank)
# Out:
# winner Florida 24 8
# loser Miami (FL) 20 nan

# %%
# Get image of school logo (winner)
# This can be saved in some image folder
image_link = winner.find("img", attrs={"class": "gamePod-game-team-logo"})["src"]

# urlretrieve(image_link, "test.svg")
print(image_link)
# Out:
# https://i.turner.ncaa.com/sites/default/files/images/logos/schools/bgl/florida.svg

# %%
# Find link to dive into a specific game
link = "https://www.ncaa.com" + game.find("a", attrs={"class": "gamePod-link"})["href"]
link
# Out:
# 'https://www.ncaa.com/game/3785117'

# %% [markdown]
# #### Game (Deep-Dive) Page

# %%
# Read page
url = link
response = requests.get(url)
soup = BeautifulSoup(response.content)

# %%
# Get top summary banner
banner = soup.find("div", attrs={"class", "gamecenter-game-banner"})

# See which team is winner (away or home)
winner_list = banner.select("span.winner")[0]
winner_team = "away" if "away" in winner_list["class"] else "home"
winner_score = int(winner_list.contents[0].replace("\n", "").strip())
print(winner_team)
print(winner_score)

# Get css
css = soup.select("style", type="text/css")
# Out:
# home
# 24

# %%
# Parse css for colors
selectors = {}
for styletag in soup.select("style"):
    css = cssutils.parseString(styletag.encode_contents())
    for rule in css:
        if rule.type == rule.STYLE_RULE:
            style = rule.selectorText
            selectors[style] = {}
            for item in rule.style:
                propertyname = item.name
                value = item.value
                selectors[style][propertyname] = value


selectors
print(selectors.get(".homeTeam-fill-primary_color").get("fill", "#fff"))
print(selectors.get(".homeTeam-fill-secondary_color").get("fill", "#fff"))
print(selectors.get(".awayTeam-fill-primary_color").get("fill", "#fff"))
print(selectors.get(".awayTeam-fill-secondary_color").get("fill", "#fff"))
# Out:
# #003087
# #00266c
# #154734
# #103829

# %%
# Get images
soup.find("div", attrs={"class", "away"}).img["src"]
# soup.find("div", attrs={"class", "home"}).img
# Out:
# '//i.turner.ncaa.com/sites/default/files/images/logos/schools/bgd/miami-fl.svg'

# %% [markdown]
# We can build the following summary from the NCAA website:
#
# **Source: Scoreboard**
# * Week Number
# * Date
# * Winner Team
# * Winner Score
# * Winner Rank
# * Winner logo
# * Loser Team
# * Loser Score
# * Loser Rank
# * Loser logo
#
# **Source: Game**
# * Winner primary color
# * Winner secondary color
# * Loser primary color
# * Loser secondary color
# * Away team
# * Home team

# %% [markdown]
# #### Navigation Bar

# %%
# Read page
url = "https://www.ncaa.com/scoreboard/football/fbs/2019/01/all-conf"
response = requests.get(url)
soup = BeautifulSoup(response.content)

# Get navigation bar
navbar = soup.find_all("div", attrs={"class": ["scoreboardDateNav-date", "hasGames"]})

# Get 1 week
week = navbar[0]

# %%
week_link = "https://www.ncaa.com" + week.select("a")[0]["href"]
print(week_link)

week_num = week.find("span", attrs={"class": "scoreboardDateNav-dayNumber"}).contents[0]
print(week_num)
# Out:
# https://www.ncaa.com/scoreboard/football/fbs/2019/01
# 1

# %% [markdown]
# ### Automate All Samples

# %%
# Set parameter
year = 2019
folder_name = "ncaa_team_logo"

# %%
# Set variables
df = []

url_home = f"https://www.ncaa.com/scoreboard/football/fbs/{year}/01/all-conf"

# Create folder to store images
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# %%
##################
# Navigation Bar #
##################

response = requests.get(url_home)
soup = BeautifulSoup(response.content)

# Get navigation bar
navbar = soup.find_all("div", attrs={"class": ["scoreboardDateNav-date", "hasGames"]})
weeks = {}

for index, week in enumerate(navbar):
    original_link = "https://www.ncaa.com" + week.select("a")[0]["href"]
    # Not sure why, but BeautifulSoup isn't parsing as expected
    if index == len(navbar) - 1:
        tail = "P"
    else:
        tail = ("0" + str(index + 1))[-2:]
    # Add {week_number : link} to dictionary
    weeks[index + 1] = (
        original_link[: -len(original_link.split("/")[-1])] + tail + "/all-conf"
    )

###################
# Scoreboard Home #
###################

for week_num in weeks:

    # Read page
    url = weeks[week_num]
    response = requests.get(url)
    soup = BeautifulSoup(response.content)

    # Get date sections
    date_sections = soup.find_all("div", attrs={"class": "gamePod_content-division"})

    for date_section in date_sections:

        # Get date from date section
        date = date_section.find_all("h6")[0].contents[0]

        # Get games within date section
        games = date_section.find_all(
            "div", attrs={"class": "gamePod gamePod-type-game status-final"}
        )

        for game in games:

            # Get results
            winner = game.find("li", attrs={"class": "winner"})
            loser = game.find("li", attrs={"class": ""})

            # Get states for winner and loser
            sides = {"winner": winner, "loser": loser}
            stats = {}
            for side_name in sides:

                side = sides.get(side_name)

                team = side.find(
                    "span", attrs={"class": "gamePod-game-team-name"}
                ).contents[0]
                score_pre = side.find(
                    "span", attrs={"class": "gamePod-game-team-score"}
                ).contents
                score = score_pre[0] if len(score_pre) > 0 else np.nan
                rank_pre = side.find(
                    "span", attrs={"class": "gamePod-game-team-rank"}
                ).contents
                rank = rank_pre[0] if len(rank_pre) > 0 else np.nan

                stats[side_name] = {
                    "team": team,
                    "score": score,
                    "rank": rank,
                }

            #                 ##############
            #                 # Save Image #
            #                 ##############

            #                 if not os.path.exists(f"{folder_name}/{team}.svg"):
            #                     image_link = side.find(
            #                         "img", attrs={"class": "gamePod-game-team-logo"}
            #                     )["src"]
            #                     urlretrieve(image_link, f"{folder_name}/{team}.svg")

            ##############
            # Get Colors #
            ##############

            # Find link to dive into a specific game
            link = (
                "https://www.ncaa.com"
                + game.find("a", attrs={"class": "gamePod-link"})["href"]
            )

            # Read page
            url = link
            response = requests.get(url)
            soup = BeautifulSoup(response.content)

            # Get top summary banner
            banner = soup.find("div", attrs={"class", "gamecenter-game-banner"})

            # See which team is winner (away or home)
            winner_list = banner.select("span.winner")[0]
            winner_team = "away" if "away" in winner_list["class"] else "home"
            loser_team = "home" if "away" in winner_list["class"] else "away"
            #             winner_score = int(winner_list.contents[0].replace("\n", "").strip())

            # Get css
            css = soup.select("style", type="text/css")

            # Parse css for colors
            selectors = {}
            for styletag in soup.select("style"):
                css = cssutils.parseString(styletag.encode_contents())
                for rule in css:
                    if rule.type == rule.STYLE_RULE:
                        style = rule.selectorText
                        selectors[style] = {}
                        for item in rule.style:
                            propertyname = item.name
                            value = item.value
                            selectors[style][propertyname] = value

            home_pc = selectors.get(".homeTeam-fill-primary_color").get("fill", "#fff")
            home_sc = selectors.get(".homeTeam-fill-secondary_color").get(
                "fill", "#fff"
            )
            away_pc = selectors.get(".awayTeam-fill-primary_color").get("fill", "#fff")
            away_sc = selectors.get(".awayTeam-fill-secondary_color").get(
                "fill", "#fff"
            )

            ##############
            # Save Image #
            ##############

            sides = {
                "home": stats.get("winner").get("team")
                if winner_team == "home"
                else stats.get("loser").get("team"),
                "away": stats.get("winner").get("team")
                if winner_team == "away"
                else stats.get("loser").get("team"),
            }

            for side in sides:
                team = sides.get(side)
                if not os.path.exists(f"{folder_name}/{team}.svg"):
                    image_link = (
                        f"https:{banner.find('div', attrs={'class': side}).img['src']}"
                    )
                    urlretrieve(image_link, f"{folder_name}/{team}.svg")

            # Add to list
            df.append(
                {
                    "week": week_num,
                    "date": date,
                    "winner_team": stats.get("winner").get("team"),
                    "winner_score": stats.get("winner").get("score"),
                    "winner_rank": stats.get("winner").get("rank"),
                    "winner_side": winner_team,
                    "winner_primary_color": home_pc
                    if winner_team == "home"
                    else away_pc,
                    "winner_secondary_color": home_sc
                    if winner_team == "home"
                    else away_sc,
                    "loser_team": stats.get("loser").get("team"),
                    "loser_score": stats.get("loser").get("score"),
                    "loser_rank": stats.get("loser").get("rank"),
                    "loser_side": loser_team,
                    "loser_primary_color": away_pc
                    if winner_team == "home"
                    else home_pc,
                    "loser_secondary_color": away_sc
                    if winner_team == "home"
                    else home_sc,
                }
            )

df = pd.DataFrame(df)
df.head()
# Out:
#    week                       date    winner_team winner_score winner_rank  \
# 0     1  Saturday, August 24, 2019        Florida           24           8
# 1     1  Saturday, August 24, 2019         Hawaii           45         NaN
# 2     1  Thursday, August 29, 2019        Buffalo           38         NaN
# 3     1  Thursday, August 29, 2019     Cincinnati           24         NaN
# 4     1  Thursday, August 29, 2019  Bowling Green           46         NaN
#
#   winner_side winner_primary_color winner_secondary_color     loser_team  \
# 0        home              #003087                #00266c     Miami (FL)
# 1        home              #154734                #103829        Arizona
# 2        home              #0057B8                #004593  Robert Morris
# 3        home              #C8102E                #a00c24           UCLA
# 4        home              #FE5000                #cb4000     Morgan St.
#
#   loser_score loser_rank loser_side loser_primary_color loser_secondary_color
# 0          20        NaN       away             #154734               #103829
# 1          38        NaN       away             #00205B               #001948
# 2          10        NaN       away             #041E42               #031834
# 3          14        NaN       away             #0072CE               #005ba4
# 4           3        NaN       away             #FC4C02               #c93c01

# %%
df.to_csv("ncaa_data.csv", index=False)

# %% [markdown]
# ## Collect Data on Conferences

# %%
# Read page content
url = "https://www.ncaa.com/standings/football/fbs"
response = requests.get(url)
soup = BeautifulSoup(response.content)

# Get list of conferences
conferences = soup.find_all("figure", attrs={"class": "standings-conference"})
all_teams = soup.find_all("div", attrs={"class": "table-wrap"})
conference_df = []

for i in range(len(conferences)):

    # Get name of conference
    conference = conferences[i].contents[1]

    # Get all teams
    teams = all_teams[i].find_all("td", attrs={"class": "standings-team"})
    for j in range(len(teams)):
        team = teams[j].contents[0]
        conference_df.append(
            {"conference": conference, "team": team,}
        )

conference_df = pd.DataFrame(conference_df)
conference_df.head(2)
# Out:
#        conference        team
# 0  Atlantic Coast  Notre Dame
# 1  Atlantic Coast     Clemson

# %%
conference_df.to_csv("ncaa_data_conference.csv", index=False)

# %% [markdown]
# ## Combine datasets

# %%
# Reload datasets
games_df = pd.read_csv("ncaa_data.csv")
conferences_df = pd.read_csv("ncaa_data_conference.csv")

# %%
# See that there are many teams that are not matched due to inconsistent names
unmatched_teams = conferences_df.merge(
    games_df, how="left", left_on="team", right_on="winner_team"
)[
    conferences_df.merge(
        games_df, how="left", left_on="team", right_on="winner_team"
    ).isnull()["winner_team"]
][
    ["conference", "team"]
]

unmatched_teams
# Out:
#                        conference                   team
# 36                 Atlantic Coast   North Carolina State
# 85                 Atlantic Coast          Florida State
# 175  American Athletic Conference          South Florida
# 176                        Big 12             Iowa State
# 190                        Big 12         Oklahoma State
# 208                        Big 12           Kansas State
# 235                       Big Ten             Ohio State
# 236                       Big Ten             Penn State
# 251                       Big Ten         Michigan State
# 309                Conference USA       Florida Atlantic
# 310                Conference USA       Western Kentucky
# 318                Conference USA       Middle Tennessee
# 319                Conference USA  Florida International
# 350                Conference USA          Southern Miss
# 352             Independents(FBS)          Brigham Young
# 361             Independents(FBS)                   Army
# 363                  Mid-American             Ball State
# 370                  Mid-American       Western Michigan
# 371                  Mid-American       Central Michigan
# 372                  Mid-American       Eastern Michigan
# 373                  Mid-American      Northern Illinois
# 382                  Mid-American             Kent State
# 397                  Mid-American                  Akron
# 401                 Mountain West         San Jose State
# 410                 Mountain West        San Diego State
# 421                 Mountain West           Fresno State
# 426                 Mountain West            Boise State
# 446                 Mountain West         Colorado State
# 447                 Mountain West             Utah State
# 448                        Pac-12                    USC
# 470                        Pac-12          Arizona State
# 499                        Pac-12           Oregon State
# 507                        Pac-12       Washington State
# 556                  Southeastern      Mississippi State
# 610                      Sun Belt      Appalachian State
# 611                      Sun Belt       Georgia Southern
# 612                      Sun Belt          Georgia State
# 618                      Sun Belt    Louisiana-Lafayette
# 621                      Sun Belt         Arkansas State
# 622                      Sun Belt            Texas State
# 623                      Sun Belt       Louisiana-Monroe

# %%
# Clean names
def replace_all(text):
    text = text.replace("St.", "State")
    text = text.replace("Mich.", "Michigan")
    text = text.replace("Tenn.", "Tennessee")
    text = text.replace("Ky.", "Kentucky")
    text = text.replace("Ga.", "Georgia")
    text = text.replace("Ill.", "Illinois")
    text = text.replace("NC", "North Carolina")
    text = text.replace("South Fla.", "South Florida")
    text = text.replace("Fla. Atlantic", "Florida Atlantic")
    text = text.replace("Miss.", "Miss")
    if (
        text == "Louisiana"
    ):  # If text.replace() is used then "Lousiana Tech" will be unintentionally changed
        text = "Louisiana-Lafayette"
    text = text.replace("La.-Monroe", "Louisiana-Monroe")
    text = text.replace("BYU", "Brigham Young")
    text = text.replace("Army West Point", "Army")
    text = text.replace("(Fla.)", "(FL)").replace("(Ohio)", "(OH)")
    text = text.replace("FIU", "Florida International")
    text = text.replace("UConn", "Connecticut")
    text = text.replace("Southern California", "USC")
    return text.strip()


# Replace names in original table
games_df["winner_team_clean"] = games_df["winner_team"].apply(lambda x: replace_all(x))
games_df["loser_team_clean"] = games_df["loser_team"].apply(lambda x: replace_all(x))

# Check that there are many teams that are not matched due to inconsistent names
unmatched_teams1 = conferences_df.merge(
    games_df, how="left", left_on="team", right_on="winner_team_clean"
)[
    conferences_df.merge(
        games_df, how="left", left_on="team", right_on="winner_team_clean"
    ).isnull()["winner_team_clean"]
][
    ["conference", "team"]
]

unmatched_teams2 = conferences_df.merge(
    games_df, how="left", left_on="team", right_on="loser_team_clean"
)[
    conferences_df.merge(
        games_df, how="left", left_on="team", right_on="loser_team_clean"
    ).isnull()["loser_team_clean"]
][
    ["conference", "team"]
]

pd.merge(unmatched_teams1, unmatched_teams2)
# Out:
# Empty DataFrame
# Columns: [conference, team]
# Index: []

# %%
# Join all columns
df = games_df.merge(
    conferences_df,
    how="left",
    left_on="winner_team_clean",
    right_on="team",
    suffixes=("", "_winner"),
).merge(
    right=conferences_df,
    how="left",
    left_on="loser_team_clean",
    right_on="team",
    suffixes=("", "_loser"),
)

# Drop unnecessary columns
df.drop(["team", "team_loser"], axis=1, inplace=True)

# Rename columns
df.rename(
    columns={"conference": "winner_conference", "conference_loser": "loser_conference"},
    inplace=True,
)

df.head()
# Out:
#    week                       date    winner_team  winner_score  winner_rank  \
# 0     1  Saturday, August 24, 2019        Florida            24          8.0
# 1     1  Saturday, August 24, 2019         Hawaii            45          NaN
# 2     1  Thursday, August 29, 2019        Buffalo            38          NaN
# 3     1  Thursday, August 29, 2019     Cincinnati            24          NaN
# 4     1  Thursday, August 29, 2019  Bowling Green            46          NaN
#
#   winner_side winner_primary_color winner_secondary_color     loser_team  \
# 0        home              #003087                #00266c     Miami (FL)
# 1        home              #154734                #103829        Arizona
# 2        home              #0057B8                #004593  Robert Morris
# 3        home              #C8102E                #a00c24           UCLA
# 4        home              #FE5000                #cb4000     Morgan St.
#
#    loser_score  loser_rank loser_side loser_primary_color  \
# 0           20         NaN       away             #154734
# 1           38         NaN       away             #00205B
# 2           10         NaN       away             #041E42
# 3           14         NaN       away             #0072CE
# 4            3         NaN       away             #FC4C02
#
#   loser_secondary_color winner_team_clean loser_team_clean  \
# 0               #103829           Florida       Miami (FL)
# 1               #001948            Hawaii          Arizona
# 2               #031834           Buffalo    Robert Morris
# 3               #005ba4        Cincinnati             UCLA
# 4               #c93c01     Bowling Green     Morgan State
#
#               winner_conference loser_conference
# 0                  Southeastern   Atlantic Coast
# 1                 Mountain West           Pac-12
# 2                  Mid-American              NaN
# 3  American Athletic Conference           Pac-12
# 4                  Mid-American              NaN

# %%
df.to_csv("ncaa_data_transformed.csv", index=False)

# %% [markdown]
# ## Explore Networkx

# %% [markdown]
# Determine placement of nodes (teams) by placing teams that have played each other closer together. Detect whether each conference has a full cycle.

# %%
# Reload datasets
df = pd.read_csv("ncaa_data_transformed.csv")
conferences_df = pd.read_csv("ncaa_data_conference.csv")

# %%
# Add index for each team belonging to a conference

df["winner_conference_index"] = np.zeros(df.shape[0])
df["loser_conference_index"] = np.zeros(df.shape[0])

conference_counts = conferences_df.groupby("conference").count()["team"]
conferences = list(df[~df.winner_conference.isna()].winner_conference.unique())

for conference in conferences:

    G = nx.from_pandas_edgelist(
        df[(df.winner_conference == conference) & (df.loser_conference == conference)],
        source="loser_team_clean",
        target="winner_team_clean",
        create_using=nx.DiGraph(),
    )

    cycles = list(nx.simple_cycles(G))

    # If no cycles are found
    if len(cycles) == 0:
        
        # Create empty dict
        mapping = {}
        
    # Else if there are cycles, then get the biggest cycle first
    else:
        
        # Add longest cycle to mapping
        cycles.sort(key=len)
        cycle = cycles[-1]
        mapping = {name: index for index, name in enumerate(cycle)}
        
        # Remove nodes we used
        G.remove_nodes_from(cycle)
    
    # Clean up remaining based on longest path
    while G.number_of_nodes() > 0:
        
        # Add longest path to mapping
        increment = len(mapping)
        path = nx.dag_longest_path(G)
        mapping.update({name: index + increment for index, name in enumerate(path)})
        
        # Remove nodes we used
        G.remove_nodes_from(path)
    
    # Update index
    df.loc[df["winner_team_clean"].isin(mapping.keys()), "winner_conference_index"] = df[df["winner_team_clean"].isin(mapping.keys())]["winner_team_clean"].apply(lambda x: mapping.get(x, 0))
    df.loc[df["loser_team_clean"].isin(mapping.keys()), "loser_conference_index"] = df[df["loser_team_clean"].isin(mapping.keys())]["loser_team_clean"].apply(lambda x: mapping.get(x, 0))

# %%
# Final cleaning

# Clean up date
df["date_mdy"] = df.date.apply(
    lambda x: datetime.strptime(x, "%A, %B %d, %Y").strftime("%m-%d-%y")
)

# Change NaN to "Other" for conference
df["winner_conference"].fillna("Other", inplace=True)
df["loser_conference"].fillna("Other", inplace=True)

# Add conference size
conferences = conferences_df.groupby("conference", as_index=False).count()
conferences = conferences.append({"conference": "Other", "team": 0}, ignore_index=True)
df["winner_conference_size"] == df["winner_conference"].apply(
    lambda x: conferences.loc[x].team
)
df["loser_conference_size"] == df["loser_conference"].apply(
    lambda x: conferences.loc[x].team, axis=1
)
# df["winner_conference_size"] = pd.merge(
#     df,
#     conferences_df.groupby("conference", as_index=False).count(),
#     left_on="winner_conference",
#     right_on="conference",
# )["team"]
# df["loser_conference_size"] = pd.merge(
#     df,
#     conferences_df.groupby("conference", as_index=False).count(),
#     left_on="loser_conference",
#     right_on="conference",
# )["team"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-79e1b23825b3> in <module>
#      16 )
#      17 df["winner_conference_size"] == df["winner_conference"].apply(
# ---> 18     lambda x: conferences.loc[x].team, axis=1
#      19 )
#      20 df["loser_conference_size"] == df["loser_conference"].apply(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in f(x)
#    3831
#    3832             def f(x):
# -> 3833                 return func(x, *args, **kwds)
#    3834
#    3835         else:
#
# TypeError: <lambda>() got an unexpected keyword argument 'axis'

# %%
pd.merge()

# %%
conferences_df.groupby("conference", as_index=False).count()
# Out:
#                       conference  team
# 0   American Athletic Conference    11
# 1                 Atlantic Coast    15
# 2                         Big 12    10
# 3                        Big Ten    14
# 4                 Conference USA    13
# 5              Independents(FBS)     4
# 6                   Mid-American    12
# 7                  Mountain West    12
# 8                         Pac-12    12
# 9                   Southeastern    14
# 10                      Sun Belt    10

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-43a073f00547> in <module>
# ----> 1 conferences.loc["Pac-12"].team
#
# AttributeError: 'list' object has no attribute 'loc'

# %%
df[df.loser_conference == "Pac-12"]
# Out:
#      week                          date    winner_team  winner_score  \
# 1       1     Saturday, August 24, 2019         Hawaii            45
# 3       1     Thursday, August 29, 2019     Cincinnati            24
# 25      1       Friday, August 30, 2019   Oklahoma St.            52
# 73      1     Saturday, August 31, 2019         Auburn            27
# 121     2  Saturday, September 07, 2019  San Diego St.            23
# ..    ...                           ...            ...           ...
# 837    15     Friday, December 06, 2019         Oregon            37
# 851    17     Friday, December 18, 2020         Oregon            31
# 855    17   Saturday, December 19, 2020           Utah            45
# 863    17   Saturday, December 19, 2020       Stanford            48
# 866    17   Saturday, December 19, 2020    Arizona St.            46
#
#      winner_rank winner_side winner_primary_color winner_secondary_color  \
# 1            NaN        home              #154734                #103829
# 3            NaN        home              #C8102E                #a00c24
# 25           NaN        away              #E35205                #b54104
# 73          16.0        away              #0C2340                #091c33
# 121          NaN        away              #A6192E                #841424
# ..           ...         ...                  ...                    ...
# 837         13.0        home              #173F35                #12322a
# 851          NaN        away              #173F35                #12322a
# 855          NaN        home              #BA0C2F                #940925
# 863          NaN        away              #9D2235                #7d1b2a
# 866          NaN        away              #8A0C3C                #6e0930
#
#               loser_team  loser_score  ...  loser_secondary_color  \
# 1                Arizona           38  ...                #001948
# 3                   UCLA           14  ...                #005ba4
# 25            Oregon St.           36  ...                #b03604
# 73                Oregon           21  ...                #12322a
# 121                 UCLA           14  ...                #005ba4
# ..                   ...          ...  ...                    ...
# 837                 Utah           15  ...                #940925
# 851  Southern California           24  ...                #7d1b2a
# 855       Washington St.           28  ...                #7d1b2a
# 863                 UCLA           47  ...                #005ba4
# 866           Oregon St.           33  ...                #b03604
#
#     winner_team_clean  loser_team_clean             winner_conference  \
# 1              Hawaii           Arizona                 Mountain West
# 3          Cincinnati              UCLA  American Athletic Conference
# 25     Oklahoma State      Oregon State                        Big 12
# 73             Auburn            Oregon                  Southeastern
# 121   San Diego State              UCLA                 Mountain West
# ..                ...               ...                           ...
# 837            Oregon              Utah                        Pac-12
# 851            Oregon               USC                        Pac-12
# 855              Utah  Washington State                        Pac-12
# 863          Stanford              UCLA                        Pac-12
# 866     Arizona State      Oregon State                        Pac-12
#
#     loser_conference winner_conference_index loser_conference_index  date_mdy  \
# 1             Pac-12                     5.0                    7.0  08-24-19
# 3             Pac-12                    10.0                    9.0  08-29-19
# 25            Pac-12                     9.0                   10.0  08-30-19
# 73            Pac-12                     8.0                    4.0  08-31-19
# 121           Pac-12                     4.0                    9.0  09-07-19
# ..               ...                     ...                    ...       ...
# 837           Pac-12                     4.0                    0.0  12-06-19
# 851           Pac-12                     4.0                    1.0  12-18-20
# 855           Pac-12                     0.0                   11.0  12-19-20
# 863           Pac-12                     8.0                    9.0  12-19-20
# 866           Pac-12                     5.0                   10.0  12-19-20
#
#      winner_conference_size  loser_conference_size
# 1                      14.0                   15.0
# 3                      14.0                   15.0
# 25                     14.0                   15.0
# 73                     14.0                   15.0
# 121                    12.0                   12.0
# ..                      ...                    ...
# 837                    10.0                    NaN
# 851                    10.0                    NaN
# 855                    10.0                    NaN
# 863                    10.0                    NaN
# 866                    10.0                    NaN
#
# [71 rows x 23 columns]

# %%
df.merge(
    conferences_df.groupby("conference", as_index=False).count(),
    left_on="loser_conference",
    right_on="conference",
)[["loser_conference", "team"]]
# Out:
#     loser_conference  team
# 0     Atlantic Coast    15
# 1     Atlantic Coast    15
# 2     Atlantic Coast    15
# 3     Atlantic Coast    15
# 4     Atlantic Coast    15
# ..               ...   ...
# 730           Big 12    10
# 731           Big 12    10
# 732           Big 12    10
# 733           Big 12    10
# 734           Big 12    10
#
# [735 rows x 2 columns]

# %%
df.to_csv("ncaa_final.csv", index=False)

# %% [markdown]
# ## Create JSON Dataset for d3.js

# %%
df = pd.read_csv("ncaa_final.csv")

# %%
# Out:
# 1      15.0
# 3      15.0
# 25     15.0
# 73     15.0
# 121    12.0
#        ...
# 837     NaN
# 851     NaN
# 855     NaN
# 863     NaN
# 866     NaN
# Name: loser_conference_size, Length: 71, dtype: float64

# %%
# Break dataframe into an exhaustive list of teams
columns = [
    "team",
    "primary_color",
    "secondary_color",
    "img_name",
    "conference",
    "conference_index",
]
teams = pd.DataFrame(columns=columns)

for side in ["winner", "loser"]:

    df_side = df[
        [
            f"{side}_team_clean",
            f"{side}_primary_color",
            f"{side}_secondary_color",
            f"{side}_team",
            f"{side}_conference",
            f"{side}_conference_index",
        ]
    ]

    df_side.columns = columns

    teams = teams.append(df_side)

teams.drop_duplicates(inplace=True)

teams.head()
# Out:
#             team primary_color secondary_color       img_name  \
# 0        Florida       #003087         #00266c        Florida
# 1         Hawaii       #154734         #103829         Hawaii
# 2        Buffalo       #0057B8         #004593        Buffalo
# 3     Cincinnati       #C8102E         #a00c24     Cincinnati
# 4  Bowling Green       #FE5000         #cb4000  Bowling Green
#
#                      conference  conference_index
# 0                  Southeastern               8.0
# 1                 Mountain West               1.0
# 2                  Mid-American               4.0
# 3  American Athletic Conference              10.0
# 4                  Mid-American               9.0

# %%
# conferences = list(nodes[nodes.conference != 'Other'].conference.unique()) + list(nodes[nodes.conference == "Other"].team.unique())

conferences = list(teams[teams.conference != "Other"].conference.unique())
nonconferences = list(teams[teams.conference == "Other"].team.unique())

nodes = []
for conference in conferences:

    members = teams[teams.conference == conference]

    nodes.append(
        {
            "conference": conference,
            "size": int(members.team.drop_duplicates().count()),
            "teams": members.to_dict(orient="records"),
        }
    )

for team in nonconferences:

    members = teams[teams.team == team]

    nodes.append(
        {
            "conference": team,
            "size": members.shape[0],
            "teams": members.to_dict(orient="records"),
        }
    )

# %%
# Links
links = df[
    [
        "week",
        "date",
        "date_mdy",
        "winner_team",
        "winner_team_clean",
        "winner_score",
        "winner_rank",
        "winner_side",
        "winner_primary_color",
        "winner_secondary_color",
        "winner_conference",
        "winner_conference_index",
        "winner_conference_size",
        "loser_team",
        "loser_team_clean",
        "loser_score",
        "loser_rank",
        "loser_side",
        "loser_primary_color",
        "loser_secondary_color",
        "loser_conference",
        "loser_conference_index",
        "loser_conference_size",
    ]
]
links.head()
# Out:
#    week                       date  date_mdy    winner_team winner_team_clean  \
# 0     1  Saturday, August 24, 2019  08-24-19        Florida           Florida
# 1     1  Saturday, August 24, 2019  08-24-19         Hawaii            Hawaii
# 2     1  Thursday, August 29, 2019  08-29-19        Buffalo           Buffalo
# 3     1  Thursday, August 29, 2019  08-29-19     Cincinnati        Cincinnati
# 4     1  Thursday, August 29, 2019  08-29-19  Bowling Green     Bowling Green
#
#    winner_score  winner_rank winner_side winner_primary_color  \
# 0            24          8.0        home              #003087
# 1            45          NaN        home              #154734
# 2            38          NaN        home              #0057B8
# 3            24          NaN        home              #C8102E
# 4            46          NaN        home              #FE5000
#
#   winner_secondary_color  ...     loser_team  loser_team_clean  loser_score  \
# 0                #00266c  ...     Miami (FL)        Miami (FL)           20
# 1                #103829  ...        Arizona           Arizona           38
# 2                #004593  ...  Robert Morris     Robert Morris           10
# 3                #a00c24  ...           UCLA              UCLA           14
# 4                #cb4000  ...     Morgan St.      Morgan State            3
#
#   loser_rank loser_side  loser_primary_color  loser_secondary_color  \
# 0        NaN       away              #154734                #103829
# 1        NaN       away              #00205B                #001948
# 2        NaN       away              #041E42                #031834
# 3        NaN       away              #0072CE                #005ba4
# 4        NaN       away              #FC4C02                #c93c01
#
#   loser_conference loser_conference_index loser_conference_size
# 0   Atlantic Coast                    1.0                  15.0
# 1           Pac-12                    7.0                  15.0
# 2            Other                    0.0                  15.0
# 3           Pac-12                    9.0                  15.0
# 4            Other                    0.0                  15.0
#
# [5 rows x 23 columns]

# %%
# Save JSON
final = {
    "nodes": nodes,
    "links": links.to_dict(orient="records"),
}

with open("ncaa.json", "w") as file:
    simplejson.dump(final, file, ignore_nan=True)

# %%
final
# Out:
# {'nodes': [{'conference': 'Southeastern',
#    'size': 14,
#    'teams': [{'team': 'Florida',
#      'primary_color': '#003087',
#      'secondary_color': '#00266c',
#      'img_name': 'Florida',
#      'conference': 'Southeastern',
#      'conference_index': 8.0},
#     {'team': 'Texas A&M',
#      'primary_color': '#500000',
#      'secondary_color': '#400000',
#      'img_name': 'Texas A&M',
#      'conference': 'Southeastern',
#      'conference_index': 5.0},
#     {'team': 'Mississippi State',
#      'primary_color': '#6F2C3F',
#      'secondary_color': '#582332',
#      'img_name': 'Mississippi St.',
#      'conference': 'Southeastern',
#      'conference_index': 3.0},
#     {'team': 'Kentucky',
#      'primary_color': '#0032A0',
#      'secondary_color': '#002880',
#      'img_name': 'Kentucky',
#      'conference': 'Southeastern',
#      'conference_index': 13.0},
#     {'team': 'Alabama',
#      'primary_color': '#9D2235',
#      'secondary_color': '#7d1b2a',
#      'img_name': 'Alabama',
#      'conference': 'Southeastern',
#      'conference_index': 6.0},
#     {'team': 'Arkansas',
#      'primary_color': '#9D2235',
#      'secondary_color': '#7d1b2a',
#      'img_name': 'Arkansas',
#      'conference': 'Southeastern',
#      'conference_index': 11.0},
#     {'team': 'Georgia',
#      'primary_color': '#DA291C',
#      'secondary_color': '#ae2016',
#      'img_name': 'Georgia',
#      'conference': 'Southeastern',
#      'conference_index': 9.0},
#     {'team': 'LSU',
#      'primary_color': '#582C83',
#      'secondary_color': '#462368',
#      'img_name': 'LSU',
#      'conference': 'Southeastern',
#      'conference_index': 12.0},
#     {'team': 'Auburn',
#      'primary_color': '#0C2340',
#      'secondary_color': '#091c33',
#      'img_name': 'Auburn',
#      'conference': 'Southeastern',
#      'conference_index': 7.0},
#     {'team': 'Missouri',
#      'primary_color': '#010101',
#      'secondary_color': '#000',
#      'img_name': 'Missouri',
#      'conference': 'Southeastern',
#      'conference_index': 0.0},
#     {'team': 'South Carolina',
#      'primary_color': '#862633',
#      'secondary_color': '#6b1e28',
#      'img_name': 'South Carolina',
#      'conference': 'Southeastern',
#      'conference_index': 10.0},
#     {'team': 'Ole Miss',
#      'primary_color': '#00205B',
#      'secondary_color': '#001948',
#      'img_name': 'Ole Miss',
#      'conference': 'Southeastern',
#      'conference_index': 2.0},
#     {'team': 'Tennessee',
#      'primary_color': '#FF8200',
#      'secondary_color': '#cc6800',
#      'img_name': 'Tennessee',
#      'conference': 'Southeastern',
#      'conference_index': 4.0},
#     {'team': 'Vanderbilt',
#      'primary_color': '#010101',
#      'secondary_color': '#000',
#      'img_name': 'Vanderbilt',
#      'conference': 'Southeastern',
#      'conference_index': 1.0},
#     {'team': 'Ole Miss',
#      'primary_color': '#C8102E',
#      'secondary_color': '#a00c24',
#      'img_name': 'Ole Miss',
#      'conference': 'Southeastern',
#      'conference_index': 2.0}]},
#   {'conference': 'Mountain West',
#    'size': 12,
#    'teams': [{'team': 'Hawaii',
#      'primary_color': '#154734',
#      'secondary_color': '#103829',
#      'img_name': 'Hawaii',
#      'conference': 'Mountain West',
#      'conference_index': 1.0},
#     {'team': 'San Jose State',
#      'primary_color': '#0032A0',
#      'secondary_color': '#002880',
#      'img_name': 'San Jose St.',
#      'conference': 'Mountain West',
#      'conference_index': 7.0},
#     {'team': 'Nevada',
#      'primary_color': '#041E42',
#      'secondary_color': '#031834',
#      'img_name': 'Nevada',
#      'conference': 'Mountain West',
#      'conference_index': 0.0},
#     {'team': 'Boise State',
#      'primary_color': '#0032A0',
#      'secondary_color': '#002880',
#      'img_name': 'Boise St.',
#      'conference': 'Mountain West',
#      'conference_index': 6.0},
#     {'team': 'Air Force',
#      'primary_color': '#0032A0',
#      'secondary_color': '#002880',
#      'img_name': 'Air Force',
#      'conference': 'Mountain West',
#      'conference_index': 5.0},
#     {'team': 'New Mexico',
#      'primary_color': '#BA0C2F',
#      'secondary_color': '#940925',
#      'img_name': 'New Mexico',
#      'conference': 'Mountain West',
#      'conference_index': 11.0},
#     {'team': 'Wyoming',
#      'primary_color': '#4E3629',
#      'secondary_color': '#3e2b20',
#      'img_name': 'Wyoming',
#      'conference': 'Mountain West',
#      'conference_index': 9.0},
#     {'team': 'San Diego State',
#      'primary_color': '#A6192E',
#      'secondary_color': '#841424',
#      'img_name': 'San Diego St.',
#      'conference': 'Mountain West',
#      'conference_index': 10.0},
#     {'team': 'UNLV',
#      'primary_color': '#C8102E',
#      'secondary_color': '#a00c24',
#      'img_name': 'UNLV',
#      'conference': 'Mountain West',
#      'conference_index': 8.0},
#     {'team': 'Colorado State',
#      'primary_color': '#2C5234',
#      'secondary_color': '#234129',
#      'img_name': 'Colorado St.',
#      'conference': 'Mountain West',
#      'conference_index': 3.0},
#     {'team': 'Utah State',
#      'primary_color': '#00263A',
#      'secondary_color': '#001e2e',
#      'img_name': 'Utah St.',
#      'conference': 'Mountain West',
#      'conference_index': 4.0},
#     {'team': 'Fresno State',
#      'primary_color': '#D50032',
#      'secondary_color': '#aa0028',
#      'img_name': 'Fresno St.',
#      'conference': 'Mountain West',
#      'conference_index': 2.0}]},
#   {'conference': 'Mid-American',
#    'size': 12,
#    'teams': [{'team': 'Buffalo',
#      'primary_color': '#0057B8',
#      'secondary_color': '#004593',
#      'img_name': 'Buffalo',
#      'conference': 'Mid-American',
#      'conference_index': 4.0},
#     {'team': 'Bowling Green',
#      'primary_color': '#FE5000',
#      'secondary_color': '#cb4000',
#      'img_name': 'Bowling Green',
#      'conference': 'Mid-American',
#      'conference_index': 9.0},
#     {'team': 'Central Michigan',
#      'primary_color': '#6F263D',
#      'secondary_color': '#581e30',
#      'img_name': 'Central Mich.',
#      'conference': 'Mid-American',
#      'conference_index': 3.0},
#     {'team': 'Ohio',
#      'primary_color': '#2C5234',
#      'secondary_color': '#234129',
#      'img_name': 'Ohio',
#      'conference': 'Mid-American',
#      'conference_index': 0.0},
#     {'team': 'Eastern Michigan',
#      'primary_color': '#046A38',
#      'secondary_color': '#03542c',
#      'img_name': 'Eastern Mich.',
#      'conference': 'Mid-American',
#      'conference_index': 7.0},
#     {'team': 'Northern Illinois',
#      'primary_color': '#BA0C2F',
#      'secondary_color': '#940925',
#      'img_name': 'Northern Ill.',
#      'conference': 'Mid-American',
#      'conference_index': 1.0},
#     {'team': 'Western Michigan',
#      'primary_color': '#693F23',
#      'secondary_color': '#54321c',
#      'img_name': 'Western Mich.',
#      'conference': 'Mid-American',
#      'conference_index': 6.0},
#     {'team': 'Kent State',
#      'primary_color': '#00205B',
#      'secondary_color': '#001948',
#      'img_name': 'Kent St.',
#      'conference': 'Mid-American',
#      'conference_index': 10.0},
#     {'team': 'Ball State',
#      'primary_color': '#BA0C2F',
#      'secondary_color': '#940925',
#      'img_name': 'Ball St.',
#      'conference': 'Mid-American',
#      'conference_index': 2.0},
#     {'team': 'Miami (OH)',
#      'primary_color': '#C8102E',
#      'secondary_color': '#a00c24',
#      'img_name': 'Miami (OH)',
#      'conference': 'Mid-American',
#      'conference_index': 5.0},
#     {'team': 'Toledo',
#      'primary_color': '#00205B',
#      'secondary_color': '#001948',
#      'img_name': 'Toledo',
#      'conference': 'Mid-American',
#      'conference_index': 8.0},
#     {'team': 'Akron',
#      'primary_color': '#041E42',
#      'secondary_color': '#031834',
#      'img_name': 'Akron',
#      'conference': 'Mid-American',
#      'conference_index': 11.0}]},
#   {'conference': 'American Athletic Conference',
#    'size': 11,
#    'teams': [{'team': 'Cincinnati',
#      'primary_color': '#C8102E',
#      'secondary_color': '#a00c24',
#      'img_name': 'Cincinnati',
#      'conference': 'American Athletic Conference',
#      'conference_index': 10.0},
#     {'team': 'UCF',
#      'primary_color': '#010101',
#      'secondary_color': '#000',
#      'img_name': 'UCF',
#      'conference': 'American Athletic Conference',
#      'conference_index': 6.0},
#     {'team': 'Tulane',
#      'primary_color': '#006747',
#      'secondary_color': '#005238',
#      'img_name': 'Tulane',
#      'conference': 'American Athletic Conference',
#      'conference_index': 1.0},
#     {'team': 'Memphis',
#      'primary_color': '#012169',
#      'secondary_color': '#001a54',
#      'img_name': 'Memphis',
#      'conference': 'American Athletic Conference',
#      'conference_index': 4.0},
#     {'team': 'Temple',
#      'primary_color': '#b30838',
#      'secondary_color': '#8f062c',
#      'img_name': 'Temple',
#      'conference': 'American Athletic Conference',
#      'conference_index': 5.0},
#     {'team': 'Navy',
#      'primary_color': '#00205B',
#      'secondary_color': '#001948',
#      'img_name': 'Navy',
#      'conference': 'American Athletic Conference',
#      'conference_index': 3.0},
#     {'team': 'SMU',
#      'primary_color': '#C8102E',
#      'secondary_color': '#a00c24',
#      'img_name': 'SMU',
#      'conference': 'American Athletic Conference',
#      'conference_index': 2.0},
#     {'team': 'East Carolina',
#      'primary_color': '#582C83',
#      'secondary_color': '#462368',
#      'img_name': 'East Carolina',
#      'conference': 'American Athletic Conference',
#      'conference_index': 8.0},
#     {'team': 'Houston',
#      'primary_color': '#C8102E',
#      'secondary_color': '#a00c24',
#      'img_name': 'Houston',
#      'conference': 'American Athletic Conference',
#      'conference_index': 0.0},
#     {'team': 'Tulsa',
#      'primary_color': '#002D72',
#      'secondary_color': '#00245b',
#      'img_name': 'Tulsa',
#      'conference': 'American Athletic Conference',
#      'conference_index': 7.0},
#     {'team': 'South Florida',
#      'primary_color': '#006747',
#      'secondary_color': '#005238',
#      'img_name': 'South Fla.',
#      'conference': 'American Athletic Conference',
#      'conference_index': 9.0},
#     {'team': 'Houston',
#      'primary_color': '#E51636',
#      'secondary_color': '#b7112b',
#      'img_name': 'Houston',
#      'conference': 'American Athletic Conference',
#      'conference_index': 0.0}]},
#   {'conference': 'Conference USA',
#    'size': 13,
#    'teams': [{'team': 'Charlotte',
#      'primary_color': '#046A38',
#      'secondary_color': '#03542c',
#      'img_name': 'Charlotte',
#      'conference': 'Conference USA',
#      'conference_index': 4.0},
#     {'team': 'UAB',
#      'primary_color': '#006341',
#      'secondary_color': '#004f34',
#      'img_name': 'UAB',
#      'conference': 'Conference USA',
#      'conference_index': 0.0},
#     {'team': 'UTSA',
#      'primary_color': '#0C2340',
#      'secondary_color': '#091c33',
#      'img_name': 'UTSA',
#      'conference': 'Conference USA',
#      'conference_index': 9.0},
#     {'team': 'Marshall',
#      'primary_color': '#00B140',
#      'secondary_color': '#008d33',
#      'img_name': 'Marshall',
#      'conference': 'Conference USA',
#      'conference_index': 3.0},
#     {'team': 'Southern Miss',
#      'primary_color': '#010101',
#      'secondary_color': '#000',
#      'img_name': 'Southern Miss.',
#      'conference': 'Conference USA',
#      'conference_index': 10.0},
#     {'team': 'North Texas',
#      'primary_color': '#007A33',
#      'secondary_color': '#006128',
#      'img_name': 'North Texas',
#      'conference': 'Conference USA',
#      'conference_index': 7.0},
#     {'team': 'UTEP',
#      'primary_color': '#041E42',
#      'secondary_color': '#031834',
#      'img_name': 'UTEP',
#      'conference': 'Conference USA',
#      'conference_index': 12.0},
#     {'team': 'Louisiana Tech',
#      'primary_color': '#003087',
#      'secondary_color': '#00266c',
#      'img_name': 'Louisiana Tech',
#      'conference': 'Conference USA',
#      'conference_index': 11.0},
#     {'team': 'Middle Tennessee',
#      'primary_color': '#005EB8',
#      'secondary_color': '#004b93',
#      'img_name': 'Middle Tenn.',
#      'conference': 'Conference USA',
#      'conference_index': 6.0},
#     {'team': 'Western Kentucky',
#      'primary_color': '#C8102E',
#      'secondary_color': '#a00c24',
#      'img_name': 'Western Ky.',
#      'conference': 'Conference USA',
#      'conference_index': 1.0},
#     {'team': 'Florida Atlantic',
#      'primary_color': '#002855',
#      'secondary_color': '#002044',
#      'img_name': 'Fla. Atlantic',
#      'conference': 'Conference USA',
#      'conference_index': 2.0},
#     {'team': 'Florida International',
#      'primary_color': '#041E42',
#      'secondary_color': '#031834',
#      'img_name': 'FIU',
#      'conference': 'Conference USA',
#      'conference_index': 5.0},
#     {'team': 'Rice',
#      'primary_color': '#00205B',
#      'secondary_color': '#001948',
#      'img_name': 'Rice',
#      'conference': 'Conference USA',
#      'conference_index': 8.0}]},
#   {'conference': 'Atlantic Coast',
#    'size': 15,
#    'teams': [{'team': 'Clemson',
#      'primary_color': '#FF6720',
#      'secondary_color': '#cc5219',
#      'img_name': 'Clemson',
#      'conference': 'Atlantic Coast',
#      'conference_index': 14.0},
#     {'team': 'Wake Forest',
#      'primary_color': '#010101',
#      'secondary_color': '#000',
#      'img_name': 'Wake Forest',
#      'conference': 'Atlantic Coast',
#      'conference_index': 3.0},
#     {'team': 'North Carolina State',
#      'primary_color': '#C8102E',
#      'secondary_color': '#a00c24',
#      'img_name': 'NC State',
#      'conference': 'Atlantic Coast',
#      'conference_index': 7.0},
#     {'team': 'North Carolina',
#      'primary_color': '#7BAFD4',
#      'secondary_color': '#628ca9',
#      'img_name': 'North Carolina',
#      'conference': 'Atlantic Coast',
#      'conference_index': 2.0},
#     {'team': 'Boston College',
#      'primary_color': '#862633',
#      'secondary_color': '#6b1e28',
#      'img_name': 'Boston College',
#      'conference': 'Atlantic Coast',
#      'conference_index': 10.0},
#     {'team': 'Syracuse',
#      'primary_color': '#DC4405',
#      'secondary_color': '#b03604',
#      'img_name': 'Syracuse',
#      'conference': 'Atlantic Coast',
#      'conference_index': 6.0},
#     {'team': 'Virginia',
#      'primary_color': '#232D4B',
#      'secondary_color': '#1c243c',
#      'img_name': 'Virginia',
#      'conference': 'Atlantic Coast',
#      'conference_index': 0.0},
#     {'team': 'Notre Dame',
#      'primary_color': '#0C2340',
#      'secondary_color': '#091c33',
#      'img_name': 'Notre Dame',
#      'conference': 'Atlantic Coast',
#      'conference_index': 13.0},
#     {'team': 'Pittsburgh',
#      'primary_color': '#003594',
#      'secondary_color': '#002a76',
#      'img_name': 'Pittsburgh',
#      'conference': 'Atlantic Coast',
#      'conference_index': 9.0},
#     {'team': 'Virginia Tech',
#      'primary_color': '#861F41',
#      'secondary_color': '#6b1834',
#      'img_name': 'Virginia Tech',
#      'conference': 'Atlantic Coast',
#      'conference_index': 4.0},
#     {'team': 'Georgia Tech',
#      'primary_color': '#B3A369',
#      'secondary_color': '#8f8254',
#      'img_name': 'Georgia Tech',
#      'conference': 'Atlantic Coast',
#      'conference_index': 8.0},
#     {'team': 'Florida State',
#      'primary_color': '#782F40',
#      'secondary_color': '#602533',
#      'img_name': 'Florida St.',
#      'conference': 'Atlantic Coast',
#      'conference_index': 12.0},
#     {'team': 'Duke',
#      'primary_color': '#002D72',
#      'secondary_color': '#00245b',
#      'img_name': 'Duke',
#      'conference': 'Atlantic Coast',
#      'conference_index': 5.0},
#     {'team': 'Louisville',
#      'primary_color': '#BA0C2F',
#      'secondary_color': '#940925',
#      'img_name': 'Louisville',
#      'conference': 'Atlantic Coast',
#      'conference_index': 11.0},
#     {'team': 'Miami (FL)',
#      'primary_color': '#154734',
#      'secondary_color': '#103829',
#      'img_name': 'Miami (FL)',
#      'conference': 'Atlantic Coast',
#      'conference_index': 1.0}]},
#   {'conference': 'Big Ten',
#    'size': 14,
#    'teams': [{'team': 'Minnesota',
#      'primary_color': '#861F41',
#      'secondary_color': '#6b1834',
#      'img_name': 'Minnesota',
#      'conference': 'Big Ten',
#      'conference_index': 10.0},
#     {'team': 'Michigan State',
#      'primary_color': '#173F35',
#      'secondary_color': '#12322a',
#      'img_name': 'Michigan St.',
#      'conference': 'Big Ten',
#      'conference_index': 8.0},
#     {'team': 'Wisconsin',
#      'primary_color': '#BA0C2F',
#      'secondary_color': '#940925',
#      'img_name': 'Wisconsin',
#      'conference': 'Big Ten',
#      'conference_index': 2.0},
#     {'team': 'Rutgers',
#      'primary_color': '#C8102E',
#      'secondary_color': '#a00c24',
#      'img_name': 'Rutgers',
#      'conference': 'Big Ten',
#      'conference_index': 11.0},
#     {'team': 'Indiana',
#      'primary_color': '#9D2235',
#      'secondary_color': '#7d1b2a',
#      'img_name': 'Indiana',
#      'conference': 'Big Ten',
#      'conference_index': 7.0},
#     {'team': 'Ohio State',
#      'primary_color': '#BA0C2F',
#      'secondary_color': '#940925',
#      'img_name': 'Ohio St.',
#      'conference': 'Big Ten',
#      'conference_index': 13.0},
#     {'team': 'Maryland',
#      'primary_color': '#C8102E',
#      'secondary_color': '#a00c24',
#      'img_name': 'Maryland',
#      'conference': 'Big Ten',
#      'conference_index': 12.0},
#     {'team': 'Nebraska',
#      'primary_color': '#C8102E',
#      'secondary_color': '#a00c24',
#      'img_name': 'Nebraska',
#      'conference': 'Big Ten',
#      'conference_index': 5.0},
#     {'team': 'Illinois',
#      'primary_color': '#E04E39',
#      'secondary_color': '#b33e2d',
#      'img_name': 'Illinois',
#      'conference': 'Big Ten',
#      'conference_index': 3.0},
#     {'team': 'Penn State',
#      'primary_color': '#041E42',
#      'secondary_color': '#031834',
#      'img_name': 'Penn St.',
#      'conference': 'Big Ten',
#      'conference_index': 9.0},
#     {'team': 'Michigan',
#      'primary_color': '#041E42',
#      'secondary_color': '#031834',
#      'img_name': 'Michigan',
#      'conference': 'Big Ten',
#      'conference_index': 1.0},
#     {'team': 'Iowa',
#      'primary_color': '#010101',
#      'secondary_color': '#000',
#      'img_name': 'Iowa',
#      'conference': 'Big Ten',
#      'conference_index': 0.0},
#     {'team': 'Purdue',
#      'primary_color': '#010101',
#      'secondary_color': '#000',
#      'img_name': 'Purdue',
#      'conference': 'Big Ten',
#      'conference_index': 6.0},
#     {'team': 'Northwestern',
#      'primary_color': '#4E2A84',
#      'secondary_color': '#3e2169',
#      'img_name': 'Northwestern',
#      'conference': 'Big Ten',
#      'conference_index': 4.0},
#     {'team': 'Ohio State',
#      'primary_color': '#CE0F3E',
#      'secondary_color': '#a40c31',
#      'img_name': 'Ohio St.',
#      'conference': 'Big Ten',
#      'conference_index': 13.0}]},
#   {'conference': 'Pac-12',
#    'size': 12,
#    'teams': [{'team': 'Arizona State',
#      'primary_color': '#7D2248',
#      'secondary_color': '#641b39',
#      'img_name': 'Arizona St.',
#      'conference': 'Pac-12',
#      'conference_index': 5.0},
#     {'team': 'Utah',
#      'primary_color': '#BA0C2F',
#      'secondary_color': '#940925',
#      'img_name': 'Utah',
#      'conference': 'Pac-12',
#      'conference_index': 0.0},
#     {'team': 'Colorado',
#      'primary_color': '#010101',
#      'secondary_color': '#000',
#      'img_name': 'Colorado',
#      'conference': 'Pac-12',
#      'conference_index': 6.0},
#     {'team': 'Washington',
#      'primary_color': '#330072',
#      'secondary_color': '#28005b',
#      'img_name': 'Washington',
#      'conference': 'Pac-12',
#      'conference_index': 2.0},
#     {'team': 'Stanford',
#      'primary_color': '#9D2235',
#      'secondary_color': '#7d1b2a',
#      'img_name': 'Stanford',
#      'conference': 'Pac-12',
#      'conference_index': 8.0},
#     {'team': 'California',
#      'primary_color': '#041E42',
#      'secondary_color': '#031834',
#      'img_name': 'California',
#      'conference': 'Pac-12',
#      'conference_index': 3.0},
#     {'team': 'Washington State',
#      'primary_color': '#9D2235',
#      'secondary_color': '#7d1b2a',
#      'img_name': 'Washington St.',
#      'conference': 'Pac-12',
#      'conference_index': 11.0},
#     {'team': 'USC',
#      'primary_color': '#9D2235',
#      'secondary_color': '#7d1b2a',
#      'img_name': 'Southern California',
#      'conference': 'Pac-12',
#      'conference_index': 1.0},
#     {'team': 'Oregon',
#      'primary_color': '#173F35',
#      'secondary_color': '#12322a',
#      'img_name': 'Oregon',
#      'conference': 'Pac-12',
#      'conference_index': 4.0},
#     {'team': 'Arizona',
#      'primary_color': '#00205B',
#      'secondary_color': '#001948',
#      'img_name': 'Arizona',
#      'conference': 'Pac-12',
#      'conference_index': 7.0},
#     {'team': 'Oregon State',
#      'primary_color': '#DC4405',
#      'secondary_color': '#b03604',
#      'img_name': 'Oregon St.',
#      'conference': 'Pac-12',
#      'conference_index': 10.0},
#     {'team': 'UCLA',
#      'primary_color': '#0072CE',
#      'secondary_color': '#005ba4',
#      'img_name': 'UCLA',
#      'conference': 'Pac-12',
#      'conference_index': 9.0},
#     {'team': 'Arizona State',
#      'primary_color': '#8A0C3C',
#      'secondary_color': '#6e0930',
#      'img_name': 'Arizona St.',
#      'conference': 'Pac-12',
#      'conference_index': 5.0}]},
#   {'conference': 'Independents(FBS)',
#    'size': 4,
#    'teams': [{'team': 'Army',
#      'primary_color': '#010101',
#      'secondary_color': '#000',
#      'img_name': 'Army West Point',
#      'conference': 'Independents(FBS)',
#      'conference_index': 3.0},
#     {'team': 'Brigham Young',
#      'primary_color': '#002E5D',
#      'secondary_color': '#00244a',
#      'img_name': 'BYU',
#      'conference': 'Independents(FBS)',
#      'conference_index': 2.0},
#     {'team': 'Liberty',
#      'primary_color': '#A6192E',
#      'secondary_color': '#841424',
#      'img_name': 'Liberty',
#      'conference': 'Independents(FBS)',
#      'conference_index': 1.0},
#     {'team': 'Massachusetts',
#      'primary_color': '#971B2F',
#      'secondary_color': '#781525',
#      'img_name': 'Massachusetts',
#      'conference': 'Independents(FBS)',
#      'conference_index': 0.0},
#     {'team': 'Liberty',
#      'primary_color': '#971A1F',
#      'secondary_color': '#781418',
#      'img_name': 'Liberty',
#      'conference': 'Independents(FBS)',
#      'conference_index': 1.0}]},
#   {'conference': 'Big 12',
#    'size': 10,
#    'teams': [{'team': 'Oklahoma State',
#      'primary_color': '#E35205',
#      'secondary_color': '#b54104',
#      'img_name': 'Oklahoma St.',
#      'conference': 'Big 12',
#      'conference_index': 4.0},
#     {'team': 'Kansas',
#      'primary_color': '#003DA5',
#      'secondary_color': '#003084',
#      'img_name': 'Kansas',
#      'conference': 'Big 12',
#      'conference_index': 9.0},
#     {'team': 'Iowa State',
#      'primary_color': '#A6192E',
#      'secondary_color': '#841424',
#      'img_name': 'Iowa St.',
#      'conference': 'Big 12',
#      'conference_index': 0.0},
#     {'team': 'West Virginia',
#      'primary_color': '#002855',
#      'secondary_color': '#002044',
#      'img_name': 'West Virginia',
#      'conference': 'Big 12',
#      'conference_index': 7.0},
#     {'team': 'Texas Tech',
#      'primary_color': '#DA291C',
#      'secondary_color': '#ae2016',
#      'img_name': 'Texas Tech',
#      'conference': 'Big 12',
#      'conference_index': 8.0},
#     {'team': 'Kansas State',
#      'primary_color': '#582C83',
#      'secondary_color': '#462368',
#      'img_name': 'Kansas St.',
#      'conference': 'Big 12',
#      'conference_index': 3.0},
#     {'team': 'Baylor',
#      'primary_color': '#1D3C34',
#      'secondary_color': '#173029',
#      'img_name': 'Baylor',
#      'conference': 'Big 12',
#      'conference_index': 1.0},
#     {'team': 'TCU',
#      'primary_color': '#582C83',
#      'secondary_color': '#462368',
#      'img_name': 'TCU',
#      'conference': 'Big 12',
#      'conference_index': 6.0},
#     {'team': 'Texas',
#      'primary_color': '#CB6015',
#      'secondary_color': '#a24c10',
#      'img_name': 'Texas',
#      'conference': 'Big 12',
#      'conference_index': 5.0},
#     {'team': 'Oklahoma',
#      'primary_color': '#9D2235',
#      'secondary_color': '#7d1b2a',
#      'img_name': 'Oklahoma',
#      'conference': 'Big 12',
#      'conference_index': 2.0}]},
#   {'conference': 'Sun Belt',
#    'size': 10,
#    'teams': [{'team': 'Georgia State',
#      'primary_color': '#0032A0',
#      'secondary_color': '#002880',
#      'img_name': 'Georgia St.',
#      'conference': 'Sun Belt',
#      'conference_index': 5.0},
#     {'team': 'Appalachian State',
#      'primary_color': '#010101',
#      'secondary_color': '#000',
#      'img_name': 'Appalachian St.',
#      'conference': 'Sun Belt',
#      'conference_index': 8.0},
#     {'team': 'Troy',
#      'primary_color': '#9D2235',
#      'secondary_color': '#7d1b2a',
#      'img_name': 'Troy',
#      'conference': 'Sun Belt',
#      'conference_index': 0.0},
#     {'team': 'Louisiana-Monroe',
#      'primary_color': '#6F2C3F',
#      'secondary_color': '#582332',
#      'img_name': 'La.-Monroe',
#      'conference': 'Sun Belt',
#      'conference_index': 6.0},
#     {'team': 'Georgia Southern',
#      'primary_color': '#041E42',
#      'secondary_color': '#031834',
#      'img_name': 'Ga. Southern',
#      'conference': 'Sun Belt',
#      'conference_index': 9.0},
#     {'team': 'Coastal Carolina',
#      'primary_color': '#007377',
#      'secondary_color': '#005c5f',
#      'img_name': 'Coastal Carolina',
#      'conference': 'Sun Belt',
#      'conference_index': 4.0},
#     {'team': 'South Alabama',
#      'primary_color': '#BF0D3E',
#      'secondary_color': '#980a31',
#      'img_name': 'South Alabama',
#      'conference': 'Sun Belt',
#      'conference_index': 2.0},
#     {'team': 'Louisiana-Lafayette',
#      'primary_color': '#C8102E',
#      'secondary_color': '#a00c24',
#      'img_name': 'Louisiana',
#      'conference': 'Sun Belt',
#      'conference_index': 7.0},
#     {'team': 'Arkansas State',
#      'primary_color': '#C8102E',
#      'secondary_color': '#a00c24',
#      'img_name': 'Arkansas St.',
#      'conference': 'Sun Belt',
#      'conference_index': 1.0},
#     {'team': 'Texas State',
#      'primary_color': '#572932',
#      'secondary_color': '#452028',
#      'img_name': 'Texas St.',
#      'conference': 'Sun Belt',
#      'conference_index': 3.0},
#     {'team': 'Georgia State',
#      'primary_color': '#264391',
#      'secondary_color': '#1e3574',
#      'img_name': 'Georgia St.',
#      'conference': 'Sun Belt',
#      'conference_index': 5.0}]},
#   {'conference': 'Connecticut',
#    'size': 1,
#    'teams': [{'team': 'Connecticut',
#      'primary_color': '#0C2340',
#      'secondary_color': '#091c33',
#      'img_name': 'UConn',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Central Ark.',
#    'size': 1,
#    'teams': [{'team': 'Central Ark.',
#      'primary_color': '#582C83',
#      'secondary_color': '#462368',
#      'img_name': 'Central Ark.',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Old Dominion',
#    'size': 1,
#    'teams': [{'team': 'Old Dominion',
#      'primary_color': '#003057',
#      'secondary_color': '#002645',
#      'img_name': 'Old Dominion',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Southern Illinois',
#    'size': 1,
#    'teams': [{'team': 'Southern Illinois',
#      'primary_color': '#6F263D',
#      'secondary_color': '#581e30',
#      'img_name': 'Southern Ill.',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'The Citadel',
#    'size': 1,
#    'teams': [{'team': 'The Citadel',
#      'primary_color': '#418FDE',
#      'secondary_color': '#3472b1',
#      'img_name': 'The Citadel',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'New Mexico State',
#    'size': 1,
#    'teams': [{'team': 'New Mexico State',
#      'primary_color': '#861F41',
#      'secondary_color': '#6b1834',
#      'img_name': 'New Mexico St.',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'App State',
#    'size': 1,
#    'teams': [{'team': 'App State',
#      'primary_color': '#010101',
#      'secondary_color': '#000',
#      'img_name': 'App State',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Robert Morris',
#    'size': 1,
#    'teams': [{'team': 'Robert Morris',
#      'primary_color': '#041E42',
#      'secondary_color': '#031834',
#      'img_name': 'Robert Morris',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Morgan State',
#    'size': 1,
#    'teams': [{'team': 'Morgan State',
#      'primary_color': '#FC4C02',
#      'secondary_color': '#c93c01',
#      'img_name': 'Morgan St.',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Wagner',
#    'size': 1,
#    'teams': [{'team': 'Wagner',
#      'primary_color': '#034638',
#      'secondary_color': '#02382c',
#      'img_name': 'Wagner',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Gardner-Webb',
#    'size': 1,
#    'teams': [{'team': 'Gardner-Webb',
#      'primary_color': '#A6192E',
#      'secondary_color': '#841424',
#      'img_name': 'Gardner-Webb',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Florida A&M',
#    'size': 1,
#    'teams': [{'team': 'Florida A&M',
#      'primary_color': '#FF8200',
#      'secondary_color': '#cc6800',
#      'img_name': 'Florida A&M',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Alabama State',
#    'size': 1,
#    'teams': [{'team': 'Alabama State',
#      'primary_color': '#010101',
#      'secondary_color': '#000',
#      'img_name': 'Alabama St.',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Albany (NY)',
#    'size': 1,
#    'teams': [{'team': 'Albany (NY)',
#      'primary_color': '#512D6D',
#      'secondary_color': '#402457',
#      'img_name': 'Albany (NY)',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'South Dakota State',
#    'size': 1,
#    'teams': [{'team': 'South Dakota State',
#      'primary_color': '#0032A0',
#      'secondary_color': '#002880',
#      'img_name': 'South Dakota St.',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Northern Colo.',
#    'size': 1,
#    'teams': [{'team': 'Northern Colo.',
#      'primary_color': '#002855',
#      'secondary_color': '#002044',
#      'img_name': 'Northern Colo.',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Indiana State',
#    'size': 1,
#    'teams': [{'team': 'Indiana State',
#      'primary_color': '#003DA5',
#      'secondary_color': '#003084',
#      'img_name': 'Indiana St.',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'UNI',
#    'size': 1,
#    'teams': [{'team': 'UNI',
#      'primary_color': '#470A68',
#      'secondary_color': '#380853',
#      'img_name': 'UNI',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Howard',
#    'size': 1,
#    'teams': [{'team': 'Howard',
#      'primary_color': '#00263E',
#      'secondary_color': '#001e31',
#      'img_name': 'Howard',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Rhode Island',
#    'size': 1,
#    'teams': [{'team': 'Rhode Island',
#      'primary_color': '#041E42',
#      'secondary_color': '#031834',
#      'img_name': 'Rhode Island',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'James Madison',
#    'size': 1,
#    'teams': [{'team': 'James Madison',
#      'primary_color': '#330072',
#      'secondary_color': '#28005b',
#      'img_name': 'James Madison',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Bucknell',
#    'size': 1,
#    'teams': [{'team': 'Bucknell',
#      'primary_color': '#071D49',
#      'secondary_color': '#05173a',
#      'img_name': 'Bucknell',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Eastern Wash.',
#    'size': 1,
#    'teams': [{'team': 'Eastern Wash.',
#      'primary_color': '#A6192E',
#      'secondary_color': '#841424',
#      'img_name': 'Eastern Wash.',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Idaho',
#    'size': 1,
#    'teams': [{'team': 'Idaho',
#      'primary_color': '#896C4C',
#      'secondary_color': '#6d563c',
#      'img_name': 'Idaho',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Holy Cross',
#    'size': 1,
#    'teams': [{'team': 'Holy Cross',
#      'primary_color': '#582C83',
#      'secondary_color': '#462368',
#      'img_name': 'Holy Cross',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Colgate',
#    'size': 1,
#    'teams': [{'team': 'Colgate',
#      'primary_color': '#862633',
#      'secondary_color': '#6b1e28',
#      'img_name': 'Colgate',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'ETSU',
#    'size': 1,
#    'teams': [{'team': 'ETSU',
#      'primary_color': '#041E42',
#      'secondary_color': '#031834',
#      'img_name': 'ETSU',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Portland State',
#    'size': 1,
#    'teams': [{'team': 'Portland State',
#      'primary_color': '#154734',
#      'secondary_color': '#103829',
#      'img_name': 'Portland St.',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Montana State',
#    'size': 1,
#    'teams': [{'team': 'Montana State',
#      'primary_color': '#00205B',
#      'secondary_color': '#001948',
#      'img_name': 'Montana St.',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'UIW',
#    'size': 1,
#    'teams': [{'team': 'UIW',
#      'primary_color': '#CB333B',
#      'secondary_color': '#a2282f',
#      'img_name': 'UIW',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Campbell',
#    'size': 1,
#    'teams': [{'team': 'Campbell',
#      'primary_color': '#E87722',
#      'secondary_color': '#b95f1b',
#      'img_name': 'Campbell',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Sam Houston State',
#    'size': 1,
#    'teams': [{'team': 'Sam Houston State',
#      'primary_color': '#FE5000',
#      'secondary_color': '#cb4000',
#      'img_name': 'Sam Houston St.',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'VMI',
#    'size': 1,
#    'teams': [{'team': 'VMI',
#      'primary_color': '#E4002B',
#      'secondary_color': '#b60022',
#      'img_name': 'VMI',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'UC Davis',
#    'size': 1,
#    'teams': [{'team': 'UC Davis',
#      'primary_color': '#002855',
#      'secondary_color': '#002044',
#      'img_name': 'UC Davis',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Illinois State',
#    'size': 1,
#    'teams': [{'team': 'Illinois State',
#      'primary_color': '#C8102E',
#      'secondary_color': '#a00c24',
#      'img_name': 'Illinois St.',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Norfolk State',
#    'size': 1,
#    'teams': [{'team': 'Norfolk State',
#      'primary_color': '#007A53',
#      'secondary_color': '#006142',
#      'img_name': 'Norfolk St.',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Monmouth',
#    'size': 1,
#    'teams': [{'team': 'Monmouth',
#      'primary_color': '#041E42',
#      'secondary_color': '#031834',
#      'img_name': 'Monmouth',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Nicholls State',
#    'size': 1,
#    'teams': [{'team': 'Nicholls State',
#      'primary_color': '#A6192E',
#      'secondary_color': '#841424',
#      'img_name': 'Nicholls St.',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Alcorn',
#    'size': 1,
#    'teams': [{'team': 'Alcorn',
#      'primary_color': '#512D6D',
#      'secondary_color': '#402457',
#      'img_name': 'Alcorn',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'SFA',
#    'size': 1,
#    'teams': [{'team': 'SFA',
#      'primary_color': '#5F259F',
#      'secondary_color': '#4c1d7f',
#      'img_name': 'SFA',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Abilene Christian',
#    'size': 1,
#    'teams': [{'team': 'Abilene Christian',
#      'primary_color': '#582C83',
#      'secondary_color': '#462368',
#      'img_name': 'Abilene Christian',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Ark.-Pine Bluff',
#    'size': 1,
#    'teams': [{'team': 'Ark.-Pine Bluff',
#      'primary_color': '#010101',
#      'secondary_color': '#000',
#      'img_name': 'Ark.-Pine Bluff',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Grambling',
#    'size': 1,
#    'teams': [{'team': 'Grambling',
#      'primary_color': '#010101',
#      'secondary_color': '#000',
#      'img_name': 'Grambling',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Houston Baptist',
#    'size': 1,
#    'teams': [{'team': 'Houston Baptist',
#      'primary_color': '#003087',
#      'secondary_color': '#00266c',
#      'img_name': 'Houston Baptist',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Weber State',
#    'size': 1,
#    'teams': [{'team': 'Weber State',
#      'primary_color': '#470A68',
#      'secondary_color': '#380853',
#      'img_name': 'Weber St.',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Southern Utah',
#    'size': 1,
#    'teams': [{'team': 'Southern Utah',
#      'primary_color': '#BA0C2F',
#      'secondary_color': '#940925',
#      'img_name': 'Southern Utah',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'William & Mary',
#    'size': 1,
#    'teams': [{'team': 'William & Mary',
#      'primary_color': '#284734',
#      'secondary_color': '#203829',
#      'img_name': 'William & Mary',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Sacramento State',
#    'size': 1,
#    'teams': [{'team': 'Sacramento State',
#      'primary_color': '#115740',
#      'secondary_color': '#0d4533',
#      'img_name': 'Sacramento St.',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Southern U.',
#    'size': 1,
#    'teams': [{'team': 'Southern U.',
#      'primary_color': '#69B3E7',
#      'secondary_color': '#548fb8',
#      'img_name': 'Southern U.',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Kennesaw State',
#    'size': 1,
#    'teams': [{'team': 'Kennesaw State',
#      'primary_color': '#010101',
#      'secondary_color': '#000',
#      'img_name': 'Kennesaw St.',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Charleston So.',
#    'size': 1,
#    'teams': [{'team': 'Charleston So.',
#      'primary_color': '#002855',
#      'secondary_color': '#002044',
#      'img_name': 'Charleston So.',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Western Caro.',
#    'size': 1,
#    'teams': [{'team': 'Western Caro.',
#      'primary_color': '#5F259F',
#      'secondary_color': '#4c1d7f',
#      'img_name': 'Western Caro.',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Fordham',
#    'size': 1,
#    'teams': [{'team': 'Fordham',
#      'primary_color': '#6F263D',
#      'secondary_color': '#581e30',
#      'img_name': 'Fordham',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Tennessee Tech',
#    'size': 1,
#    'teams': [{'team': 'Tennessee Tech',
#      'primary_color': '#753BBD',
#      'secondary_color': '#5d2f97',
#      'img_name': 'Tennessee Tech',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Eastern Illinois',
#    'size': 1,
#    'teams': [{'team': 'Eastern Illinois',
#      'primary_color': '#003594',
#      'secondary_color': '#002a76',
#      'img_name': 'Eastern Ill.',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Richmond',
#    'size': 1,
#    'teams': [{'team': 'Richmond',
#      'primary_color': '#BA0C2F',
#      'secondary_color': '#940925',
#      'img_name': 'Richmond',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Western Illinois',
#    'size': 1,
#    'teams': [{'team': 'Western Illinois',
#      'primary_color': '#500778',
#      'secondary_color': '#400560',
#      'img_name': 'Western Ill.',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Murray State',
#    'size': 1,
#    'teams': [{'team': 'Murray State',
#      'primary_color': '#0C2340',
#      'secondary_color': '#091c33',
#      'img_name': 'Murray St.',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'N.C. A&T',
#    'size': 1,
#    'teams': [{'team': 'N.C. A&T',
#      'primary_color': '#002D72',
#      'secondary_color': '#00245b',
#      'img_name': 'N.C. A&T',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Maine',
#    'size': 1,
#    'teams': [{'team': 'Maine',
#      'primary_color': '#0C2340',
#      'secondary_color': '#091c33',
#      'img_name': 'Maine',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'McNeese',
#    'size': 1,
#    'teams': [{'team': 'McNeese',
#      'primary_color': '#003087',
#      'secondary_color': '#00266c',
#      'img_name': 'McNeese',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Furman',
#    'size': 1,
#    'teams': [{'team': 'Furman',
#      'primary_color': '#582C83',
#      'secondary_color': '#462368',
#      'img_name': 'Furman',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'South Dakota',
#    'size': 1,
#    'teams': [{'team': 'South Dakota',
#      'primary_color': '#BA0C2F',
#      'secondary_color': '#940925',
#      'img_name': 'South Dakota',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Tennessee State',
#    'size': 1,
#    'teams': [{'team': 'Tennessee State',
#      'primary_color': '#001489',
#      'secondary_color': '#00106d',
#      'img_name': 'Tennessee St.',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Eastern Kentucky',
#    'size': 1,
#    'teams': [{'team': 'Eastern Kentucky',
#      'primary_color': '#6F263D',
#      'secondary_color': '#581e30',
#      'img_name': 'Eastern Ky.',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Jackson State',
#    'size': 1,
#    'teams': [{'team': 'Jackson State',
#      'primary_color': '#041E42',
#      'secondary_color': '#031834',
#      'img_name': 'Jackson St.',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'UT Martin',
#    'size': 1,
#    'teams': [{'team': 'UT Martin',
#      'primary_color': '#0C2340',
#      'secondary_color': '#091c33',
#      'img_name': 'UT Martin',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Stony Brook',
#    'size': 1,
#    'teams': [{'team': 'Stony Brook',
#      'primary_color': '#A6192E',
#      'secondary_color': '#841424',
#      'img_name': 'Stony Brook',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Prairie View',
#    'size': 1,
#    'teams': [{'team': 'Prairie View',
#      'primary_color': '#582C83',
#      'secondary_color': '#462368',
#      'img_name': 'Prairie View',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Northern Ariz.',
#    'size': 1,
#    'teams': [{'team': 'Northern Ariz.',
#      'primary_color': '#00205B',
#      'secondary_color': '#001948',
#      'img_name': 'Northern Ariz.',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Chattanooga',
#    'size': 1,
#    'teams': [{'team': 'Chattanooga',
#      'primary_color': '#002855',
#      'secondary_color': '#002044',
#      'img_name': 'Chattanooga',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Southeastern La.',
#    'size': 1,
#    'teams': [{'team': 'Southeastern La.',
#      'primary_color': '#006341',
#      'secondary_color': '#004f34',
#      'img_name': 'Southeastern La.',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Bethune-Cookman',
#    'size': 1,
#    'teams': [{'team': 'Bethune-Cookman',
#      'primary_color': '#6F263D',
#      'secondary_color': '#581e30',
#      'img_name': 'Bethune-Cookman',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Cal Poly',
#    'size': 1,
#    'teams': [{'team': 'Cal Poly',
#      'primary_color': '#2C5234',
#      'secondary_color': '#234129',
#      'img_name': 'Cal Poly',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Idaho State',
#    'size': 1,
#    'teams': [{'team': 'Idaho State',
#      'primary_color': '#FF6720',
#      'secondary_color': '#cc5219',
#      'img_name': 'Idaho St.',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'South Carolina State',
#    'size': 1,
#    'teams': [{'team': 'South Carolina State',
#      'primary_color': '#862633',
#      'secondary_color': '#6b1e28',
#      'img_name': 'South Carolina St.',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Lamar University',
#    'size': 1,
#    'teams': [{'team': 'Lamar University',
#      'primary_color': '#D50032',
#      'secondary_color': '#aa0028',
#      'img_name': 'Lamar University',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'New Hampshire',
#    'size': 1,
#    'teams': [{'team': 'New Hampshire',
#      'primary_color': '#041E42',
#      'secondary_color': '#031834',
#      'img_name': 'New Hampshire',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Northwestern State',
#    'size': 1,
#    'teams': [{'team': 'Northwestern State',
#      'primary_color': '#54209e',
#      'secondary_color': '#43197e',
#      'img_name': 'Northwestern St.',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Texas Southern',
#    'size': 1,
#    'teams': [{'team': 'Texas Southern',
#      'primary_color': '#6F263D',
#      'secondary_color': '#581e30',
#      'img_name': 'Texas Southern',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Southeast Mo. State',
#    'size': 1,
#    'teams': [{'team': 'Southeast Mo. State',
#      'primary_color': '#010101',
#      'secondary_color': '#000',
#      'img_name': 'Southeast Mo. St.',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Missouri State',
#    'size': 1,
#    'teams': [{'team': 'Missouri State',
#      'primary_color': '#6F2C3F',
#      'secondary_color': '#582332',
#      'img_name': 'Missouri St.',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Montana',
#    'size': 1,
#    'teams': [{'team': 'Montana',
#      'primary_color': '#6F2C3F',
#      'secondary_color': '#582332',
#      'img_name': 'Montana',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Elon',
#    'size': 1,
#    'teams': [{'team': 'Elon',
#      'primary_color': '#76232F',
#      'secondary_color': '#5e1c25',
#      'img_name': 'Elon',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Central Conn. State',
#    'size': 1,
#    'teams': [{'team': 'Central Conn. State',
#      'primary_color': '#003087',
#      'secondary_color': '#00266c',
#      'img_name': 'Central Conn. St.',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Hampton',
#    'size': 1,
#    'teams': [{'team': 'Hampton',
#      'primary_color': '#0033A0',
#      'secondary_color': '#002880',
#      'img_name': 'Hampton',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Delaware',
#    'size': 1,
#    'teams': [{'team': 'Delaware',
#      'primary_color': '#004C97',
#      'secondary_color': '#003c78',
#      'img_name': 'Delaware',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Towson',
#    'size': 1,
#    'teams': [{'team': 'Towson',
#      'primary_color': '#010101',
#      'secondary_color': '#000',
#      'img_name': 'Towson',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Wofford',
#    'size': 1,
#    'teams': [{'team': 'Wofford',
#      'primary_color': '#8C714C',
#      'secondary_color': '#705a3c',
#      'img_name': 'Wofford',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
#   {'conference': 'Samford',
#    'size': 1,
#    'teams': [{'team': 'Samford',
#      'primary_color': '#0C2340',
#      'secondary_color': '#091c33',
#      'img_name': 'Samford',
#      'conference': 'Other',
#      'conference_index': 0.0}]},
# ...
#    'winner_team_clean': 'Utah',
#    'winner_score': 45,
#    'winner_rank': nan,
#    'winner_side': 'home',
#    'winner_primary_color': '#BA0C2F',
#    'winner_secondary_color': '#940925',
#    'winner_conference': 'Pac-12',
#    'winner_conference_index': 0.0,
#    'winner_conference_size': 10.0,
#    'loser_team': 'Washington St.',
#    'loser_team_clean': 'Washington State',
#    'loser_score': 28,
#    'loser_rank': nan,
#    'loser_side': 'away',
#    'loser_primary_color': '#9D2235',
#    'loser_secondary_color': '#7d1b2a',
#    'loser_conference': 'Pac-12',
#    'loser_conference_index': 11.0,
#    'loser_conference_size': nan},
#   {'week': 17,
#    'date': 'Saturday, December 19, 2020',
#    'date_mdy': '12-19-20',
#    'winner_team': 'Army West Point',
#    'winner_team_clean': 'Army',
#    'winner_score': 10,
#    'winner_rank': nan,
#    'winner_side': 'home',
#    'winner_primary_color': '#010101',
#    'winner_secondary_color': '#000',
#    'winner_conference': 'Independents(FBS)',
#    'winner_conference_index': 3.0,
#    'winner_conference_size': 10.0,
#    'loser_team': 'Air Force',
#    'loser_team_clean': 'Air Force',
#    'loser_score': 7,
#    'loser_rank': nan,
#    'loser_side': 'away',
#    'loser_primary_color': '#0032A0',
#    'loser_secondary_color': '#002880',
#    'loser_conference': 'Mountain West',
#    'loser_conference_index': 5.0,
#    'loser_conference_size': nan},
#   {'week': 17,
#    'date': 'Saturday, December 19, 2020',
#    'date_mdy': '12-19-20',
#    'winner_team': 'Mississippi St.',
#    'winner_team_clean': 'Mississippi State',
#    'winner_score': 51,
#    'winner_rank': nan,
#    'winner_side': 'home',
#    'winner_primary_color': '#6F2C3F',
#    'winner_secondary_color': '#582332',
#    'winner_conference': 'Southeastern',
#    'winner_conference_index': 3.0,
#    'winner_conference_size': 10.0,
#    'loser_team': 'Missouri',
#    'loser_team_clean': 'Missouri',
#    'loser_score': 32,
#    'loser_rank': nan,
#    'loser_side': 'away',
#    'loser_primary_color': '#010101',
#    'loser_secondary_color': '#000',
#    'loser_conference': 'Southeastern',
#    'loser_conference_index': 0.0,
#    'loser_conference_size': nan},
#   {'week': 17,
#    'date': 'Saturday, December 19, 2020',
#    'date_mdy': '12-19-20',
#    'winner_team': 'LSU',
#    'winner_team_clean': 'LSU',
#    'winner_score': 53,
#    'winner_rank': nan,
#    'winner_side': 'home',
#    'winner_primary_color': '#582C83',
#    'winner_secondary_color': '#462368',
#    'winner_conference': 'Southeastern',
#    'winner_conference_index': 12.0,
#    'winner_conference_size': 10.0,
#    'loser_team': 'Ole Miss',
#    'loser_team_clean': 'Ole Miss',
#    'loser_score': 48,
#    'loser_rank': nan,
#    'loser_side': 'away',
#    'loser_primary_color': '#C8102E',
#    'loser_secondary_color': '#a00c24',
#    'loser_conference': 'Southeastern',
#    'loser_conference_index': 2.0,
#    'loser_conference_size': nan},
#   {'week': 17,
#    'date': 'Saturday, December 19, 2020',
#    'date_mdy': '12-19-20',
#    'winner_team': 'Clemson',
#    'winner_team_clean': 'Clemson',
#    'winner_score': 34,
#    'winner_rank': 3.0,
#    'winner_side': 'away',
#    'winner_primary_color': '#FF6720',
#    'winner_secondary_color': '#cc5219',
#    'winner_conference': 'Atlantic Coast',
#    'winner_conference_index': 14.0,
#    'winner_conference_size': 10.0,
#    'loser_team': 'Notre Dame',
#    'loser_team_clean': 'Notre Dame',
#    'loser_score': 10,
#    'loser_rank': 2.0,
#    'loser_side': 'home',
#    'loser_primary_color': '#0C2340',
#    'loser_secondary_color': '#091c33',
#    'loser_conference': 'Atlantic Coast',
#    'loser_conference_index': 13.0,
#    'loser_conference_size': nan},
#   {'week': 17,
#    'date': 'Saturday, December 19, 2020',
#    'date_mdy': '12-19-20',
#    'winner_team': 'Wisconsin',
#    'winner_team_clean': 'Wisconsin',
#    'winner_score': 20,
#    'winner_rank': nan,
#    'winner_side': 'home',
#    'winner_primary_color': '#BA0C2F',
#    'winner_secondary_color': '#940925',
#    'winner_conference': 'Big Ten',
#    'winner_conference_index': 2.0,
#    'winner_conference_size': 10.0,
#    'loser_team': 'Minnesota',
#    'loser_team_clean': 'Minnesota',
#    'loser_score': 17,
#    'loser_rank': nan,
#    'loser_side': 'away',
#    'loser_primary_color': '#861F41',
#    'loser_secondary_color': '#6b1834',
#    'loser_conference': 'Big Ten',
#    'loser_conference_index': 10.0,
#    'loser_conference_size': nan},
#   {'week': 17,
#    'date': 'Saturday, December 19, 2020',
#    'date_mdy': '12-19-20',
#    'winner_team': 'San Jose St.',
#    'winner_team_clean': 'San Jose State',
#    'winner_score': 34,
#    'winner_rank': 24.0,
#    'winner_side': 'home',
#    'winner_primary_color': '#0032A0',
#    'winner_secondary_color': '#002880',
#    'winner_conference': 'Mountain West',
#    'winner_conference_index': 7.0,
#    'winner_conference_size': 10.0,
#    'loser_team': 'Boise St.',
#    'loser_team_clean': 'Boise State',
#    'loser_score': 20,
#    'loser_rank': nan,
#    'loser_side': 'away',
#    'loser_primary_color': '#0032A0',
#    'loser_secondary_color': '#002880',
#    'loser_conference': 'Mountain West',
#    'loser_conference_index': 6.0,
#    'loser_conference_size': nan},
#   {'week': 17,
#    'date': 'Saturday, December 19, 2020',
#    'date_mdy': '12-19-20',
#    'winner_team': 'Penn St.',
#    'winner_team_clean': 'Penn State',
#    'winner_score': 56,
#    'winner_rank': nan,
#    'winner_side': 'home',
#    'winner_primary_color': '#041E42',
#    'winner_secondary_color': '#031834',
#    'winner_conference': 'Big Ten',
#    'winner_conference_index': 9.0,
#    'winner_conference_size': 10.0,
#    'loser_team': 'Illinois',
#    'loser_team_clean': 'Illinois',
#    'loser_score': 21,
#    'loser_rank': nan,
#    'loser_side': 'away',
#    'loser_primary_color': '#E04E39',
#    'loser_secondary_color': '#b33e2d',
#    'loser_conference': 'Big Ten',
#    'loser_conference_index': 3.0,
#    'loser_conference_size': nan},
#   {'week': 17,
#    'date': 'Saturday, December 19, 2020',
#    'date_mdy': '12-19-20',
#    'winner_team': 'Stanford',
#    'winner_team_clean': 'Stanford',
#    'winner_score': 48,
#    'winner_rank': nan,
#    'winner_side': 'away',
#    'winner_primary_color': '#9D2235',
#    'winner_secondary_color': '#7d1b2a',
#    'winner_conference': 'Pac-12',
#    'winner_conference_index': 8.0,
#    'winner_conference_size': 10.0,
#    'loser_team': 'UCLA',
#    'loser_team_clean': 'UCLA',
#    'loser_score': 47,
#    'loser_rank': nan,
#    'loser_side': 'home',
#    'loser_primary_color': '#0072CE',
#    'loser_secondary_color': '#005ba4',
#    'loser_conference': 'Pac-12',
#    'loser_conference_index': 9.0,
#    'loser_conference_size': nan},
#   {'week': 17,
#    'date': 'Saturday, December 19, 2020',
#    'date_mdy': '12-19-20',
#    'winner_team': 'Alabama',
#    'winner_team_clean': 'Alabama',
#    'winner_score': 52,
#    'winner_rank': 1.0,
#    'winner_side': 'away',
#    'winner_primary_color': '#9D2235',
#    'winner_secondary_color': '#7d1b2a',
#    'winner_conference': 'Southeastern',
#    'winner_conference_index': 6.0,
#    'winner_conference_size': 10.0,
#    'loser_team': 'Florida',
#    'loser_team_clean': 'Florida',
#    'loser_score': 46,
#    'loser_rank': 7.0,
#    'loser_side': 'home',
#    'loser_primary_color': '#003087',
#    'loser_secondary_color': '#00266c',
#    'loser_conference': 'Southeastern',
#    'loser_conference_index': 8.0,
#    'loser_conference_size': nan},
#   {'week': 17,
#    'date': 'Saturday, December 19, 2020',
#    'date_mdy': '12-19-20',
#    'winner_team': 'Cincinnati',
#    'winner_team_clean': 'Cincinnati',
#    'winner_score': 27,
#    'winner_rank': 9.0,
#    'winner_side': 'home',
#    'winner_primary_color': '#C8102E',
#    'winner_secondary_color': '#a00c24',
#    'winner_conference': 'American Athletic Conference',
#    'winner_conference_index': 10.0,
#    'winner_conference_size': 10.0,
#    'loser_team': 'Tulsa',
#    'loser_team_clean': 'Tulsa',
#    'loser_score': 24,
#    'loser_rank': 23.0,
#    'loser_side': 'away',
#    'loser_primary_color': '#002D72',
#    'loser_secondary_color': '#00245b',
#    'loser_conference': 'American Athletic Conference',
#    'loser_conference_index': 7.0,
#    'loser_conference_size': nan},
#   {'week': 17,
#    'date': 'Saturday, December 19, 2020',
#    'date_mdy': '12-19-20',
#    'winner_team': 'Arizona St.',
#    'winner_team_clean': 'Arizona State',
#    'winner_score': 46,
#    'winner_rank': nan,
#    'winner_side': 'away',
#    'winner_primary_color': '#8A0C3C',
#    'winner_secondary_color': '#6e0930',
#    'winner_conference': 'Pac-12',
#    'winner_conference_index': 5.0,
#    'winner_conference_size': 10.0,
#    'loser_team': 'Oregon St.',
#    'loser_team_clean': 'Oregon State',
#    'loser_score': 33,
#    'loser_rank': nan,
#    'loser_side': 'home',
#    'loser_primary_color': '#DC4405',
#    'loser_secondary_color': '#b03604',
#    'loser_conference': 'Pac-12',
#    'loser_conference_index': 10.0,
#    'loser_conference_size': nan},
#   {'week': 17,
#    'date': 'Monday, December 21, 2020',
#    'date_mdy': '12-21-20',
#    'winner_team': 'App State',
#    'winner_team_clean': 'App State',
#    'winner_score': 56,
#    'winner_rank': nan,
#    'winner_side': 'away',
#    'winner_primary_color': '#010101',
#    'winner_secondary_color': '#000',
#    'winner_conference': 'Other',
#    'winner_conference_index': 0.0,
#    'winner_conference_size': 10.0,
#    'loser_team': 'North Texas',
#    'loser_team_clean': 'North Texas',
#    'loser_score': 28,
#    'loser_rank': nan,
#    'loser_side': 'home',
#    'loser_primary_color': '#007A33',
#    'loser_secondary_color': '#006128',
#    'loser_conference': 'Conference USA',
#    'loser_conference_index': 7.0,
#    'loser_conference_size': nan},
#   {'week': 17,
#    'date': 'Tuesday, December 22, 2020',
#    'date_mdy': '12-22-20',
#    'winner_team': 'Nevada',
#    'winner_team_clean': 'Nevada',
#    'winner_score': 38,
#    'winner_rank': nan,
#    'winner_side': 'home',
#    'winner_primary_color': '#041E42',
#    'winner_secondary_color': '#031834',
#    'winner_conference': 'Mountain West',
#    'winner_conference_index': 0.0,
#    'winner_conference_size': nan,
#    'loser_team': 'Tulane',
#    'loser_team_clean': 'Tulane',
#    'loser_score': 27,
#    'loser_rank': nan,
#    'loser_side': 'away',
#    'loser_primary_color': '#006747',
#    'loser_secondary_color': '#005238',
#    'loser_conference': 'American Athletic Conference',
#    'loser_conference_index': 1.0,
#    'loser_conference_size': nan},
#   {'week': 17,
#    'date': 'Tuesday, December 22, 2020',
#    'date_mdy': '12-22-20',
#    'winner_team': 'BYU',
#    'winner_team_clean': 'Brigham Young',
#    'winner_score': 49,
#    'winner_rank': 16.0,
#    'winner_side': 'home',
#    'winner_primary_color': '#002E5D',
#    'winner_secondary_color': '#00244a',
#    'winner_conference': 'Independents(FBS)',
#    'winner_conference_index': 2.0,
#    'winner_conference_size': nan,
#    'loser_team': 'UCF',
#    'loser_team_clean': 'UCF',
#    'loser_score': 23,
#    'loser_rank': nan,
#    'loser_side': 'away',
#    'loser_primary_color': '#010101',
#    'loser_secondary_color': '#000',
#    'loser_conference': 'American Athletic Conference',
#    'loser_conference_index': 6.0,
#    'loser_conference_size': nan},
#   {'week': 17,
#    'date': 'Wednesday, December 23, 2020',
#    'date_mdy': '12-23-20',
#    'winner_team': 'Ga. Southern',
#    'winner_team_clean': 'Georgia Southern',
#    'winner_score': 38,
#    'winner_rank': nan,
#    'winner_side': 'home',
#    'winner_primary_color': '#041E42',
#    'winner_secondary_color': '#031834',
#    'winner_conference': 'Sun Belt',
#    'winner_conference_index': 9.0,
#    'winner_conference_size': nan,
#    'loser_team': 'Louisiana Tech',
#    'loser_team_clean': 'Louisiana Tech',
#    'loser_score': 3,
#    'loser_rank': nan,
#    'loser_side': 'away',
#    'loser_primary_color': '#003087',
#    'loser_secondary_color': '#00266c',
#    'loser_conference': 'Conference USA',
#    'loser_conference_index': 11.0,
#    'loser_conference_size': nan},
#   {'week': 17,
#    'date': 'Wednesday, December 23, 2020',
#    'date_mdy': '12-23-20',
#    'winner_team': 'Memphis',
#    'winner_team_clean': 'Memphis',
#    'winner_score': 25,
#    'winner_rank': nan,
#    'winner_side': 'away',
#    'winner_primary_color': '#012169',
#    'winner_secondary_color': '#001a54',
#    'winner_conference': 'American Athletic Conference',
#    'winner_conference_index': 4.0,
#    'winner_conference_size': nan,
#    'loser_team': 'Fla. Atlantic',
#    'loser_team_clean': 'Florida Atlantic',
#    'loser_score': 10,
#    'loser_rank': nan,
#    'loser_side': 'home',
#    'loser_primary_color': '#002855',
#    'loser_secondary_color': '#002044',
#    'loser_conference': 'Conference USA',
#    'loser_conference_index': 2.0,
#    'loser_conference_size': nan},
#   {'week': 17,
#    'date': 'Thursday, December 24, 2020',
#    'date_mdy': '12-24-20',
#    'winner_team': 'Hawaii',
#    'winner_team_clean': 'Hawaii',
#    'winner_score': 28,
#    'winner_rank': nan,
#    'winner_side': 'away',
#    'winner_primary_color': '#154734',
#    'winner_secondary_color': '#103829',
#    'winner_conference': 'Mountain West',
#    'winner_conference_index': 1.0,
#    'winner_conference_size': nan,
#    'loser_team': 'Houston',
#    'loser_team_clean': 'Houston',
#    'loser_score': 14,
#    'loser_rank': nan,
#    'loser_side': 'home',
#    'loser_primary_color': '#E51636',
#    'loser_secondary_color': '#b7112b',
#    'loser_conference': 'American Athletic Conference',
#    'loser_conference_index': 0.0,
#    'loser_conference_size': nan},
#   {'week': 17,
#    'date': 'Friday, December 25, 2020',
#    'date_mdy': '12-25-20',
#    'winner_team': 'Buffalo',
#    'winner_team_clean': 'Buffalo',
#    'winner_score': 17,
#    'winner_rank': nan,
#    'winner_side': 'home',
#    'winner_primary_color': '#0057B8',
#    'winner_secondary_color': '#004593',
#    'winner_conference': 'Mid-American',
#    'winner_conference_index': 4.0,
#    'winner_conference_size': nan,
#    'loser_team': 'Marshall',
#    'loser_team_clean': 'Marshall',
#    'loser_score': 10,
#    'loser_rank': nan,
#    'loser_side': 'away',
#    'loser_primary_color': '#00B140',
#    'loser_secondary_color': '#008d33',
#    'loser_conference': 'Conference USA',
#    'loser_conference_index': 3.0,
#    'loser_conference_size': nan},
#   {'week': 17,
#    'date': 'Saturday, December 26, 2020',
#    'date_mdy': '12-26-20',
#    'winner_team': 'Georgia St.',
#    'winner_team_clean': 'Georgia State',
#    'winner_score': 39,
#    'winner_rank': nan,
#    'winner_side': 'home',
#    'winner_primary_color': '#264391',
#    'winner_secondary_color': '#1e3574',
#    'winner_conference': 'Sun Belt',
#    'winner_conference_index': 5.0,
#    'winner_conference_size': nan,
#    'loser_team': 'Western Ky.',
#    'loser_team_clean': 'Western Kentucky',
#    'loser_score': 21,
#    'loser_rank': nan,
#    'loser_side': 'away',
#    'loser_primary_color': '#C8102E',
#    'loser_secondary_color': '#a00c24',
#    'loser_conference': 'Conference USA',
#    'loser_conference_index': 1.0,
#    'loser_conference_size': nan},
#   {'week': 17,
#    'date': 'Saturday, December 26, 2020',
#    'date_mdy': '12-26-20',
#    'winner_team': 'Louisiana',
#    'winner_team_clean': 'Louisiana-Lafayette',
#    'winner_score': 31,
#    'winner_rank': 19.0,
#    'winner_side': 'away',
#    'winner_primary_color': '#C8102E',
#    'winner_secondary_color': '#a00c24',
#    'winner_conference': 'Sun Belt',
#    'winner_conference_index': 7.0,
#    'winner_conference_size': nan,
#    'loser_team': 'UTSA',
#    'loser_team_clean': 'UTSA',
#    'loser_score': 24,
#    'loser_rank': nan,
#    'loser_side': 'home',
#    'loser_primary_color': '#0C2340',
#    'loser_secondary_color': '#091c33',
#    'loser_conference': 'Conference USA',
#    'loser_conference_index': 9.0,
#    'loser_conference_size': nan},
#   {'week': 17,
#    'date': 'Saturday, December 26, 2020',
#    'date_mdy': '12-26-20',
#    'winner_team': 'Liberty',
#    'winner_team_clean': 'Liberty',
#    'winner_score': 37,
#    'winner_rank': nan,
#    'winner_side': 'away',
#    'winner_primary_color': '#971A1F',
#    'winner_secondary_color': '#781418',
#    'winner_conference': 'Independents(FBS)',
#    'winner_conference_index': 1.0,
#    'winner_conference_size': nan,
#    'loser_team': 'Coastal Carolina',
#    'loser_team_clean': 'Coastal Carolina',
#    'loser_score': 34,
#    'loser_rank': 12.0,
#    'loser_side': 'home',
#    'loser_primary_color': '#007377',
#    'loser_secondary_color': '#005c5f',
#    'loser_conference': 'Sun Belt',
#    'loser_conference_index': 4.0,
#    'loser_conference_size': nan}]}
